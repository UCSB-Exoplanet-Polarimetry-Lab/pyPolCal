# %%
import sys
import os

# Add the directory containing instruments.py to the Python path
custom_module_path = "/home/rebeccaz/Github/vampires_calibration"
sys.path.append(custom_module_path)

import plotting_rewrite as plotting

h5_file_path = "/home/rebeccaz/Github/vampires_calibration/mcmc/results/670nm.h5"
txt_file_path = "/home/rebeccaz/Github/vampires_calibration/scipy_minimize/data_files/produced/675-50nm_no_IMR_offset_or_IMR_and_HWP_constraints.txt"

# %%
chain, names = plotting.load_chain_and_labels(h5_file_path, txt_file_path, include_logf = True)
all_step_range = (0, None)
corner_plot_step_range = (185000, 186000)

# Optional: Check chain shape after loading
print("Chain shape (nsteps, nwalkers, ndim):", chain.shape)

# Plot trace plots for MCMC chains
plotting.plot_trace(chain, names, step_range=all_step_range, max_walkers=100)

# Plot corner plot from flattened chain
plotting.plot_corner_flat(chain, names, step_range=corner_plot_step_range)

# Print median ± std for each parameter
plotting.summarize_posteriors(chain, names, step_range=corner_plot_step_range)
# Out:
# Chain shape (nsteps, nwalkers, ndim): (200000, 28, 13)
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# dichroic.phi (waves): 0.01373 ± 0.20538
# dichroic.epsilon: 0.26178 ± 0.11282
# dichroic.theta: 44.48338 ± 38.39404
# flc.phi (waves): 0.49751 ± 0.02329
# flc.delta_theta: 0.39779 ± 0.51546
# optics.phi (waves): 0.87246 ± 0.03882
# optics.epsilon: 0.00163 ± 0.00199
# optics.theta: -83.15564 ± 1.71515
# image_rotator.phi (waves): 0.31815 ± 0.00160
# hwp.phi (waves): 0.45962 ± 0.00154
# hwp.delta_theta: -1.14916 ± 0.45997
# lp.theta: 0.52993 ± 0.92610
# log_f: -8.20205 ± 1.27089

# %% [markdown]
# # Plotting Random Chains for Fitting

# %%
import sys
import os

# Add the directory containing instruments.py to the Python path
custom_module_path = "/home/rebeccaz/Github/vampires_calibration"
sys.path.append(custom_module_path)

import plotting_rewrite as plotting
import numpy as np

all_step_range = (0, None)
corner_plot_step_range = (24000, 25000)

# Define the system configuration dictionary
system_dict = {
    "components": {
        "wollaston": {
            "type": "wollaston_prism_function",
            "properties": {"beam": "o", "transmission_ratio": 1.18},
        },
        "dichroic": {
            "type": "diattenuator_retarder_function",
            "properties": {"phi": 0, "epsilon": 0, "theta": 0},
        },
        "flc": {
            "type": "general_retarder_function",
            "properties": {"phi": 0.5 * 2 * np.pi, "theta": 0, "delta_theta": 0},
        },
        "optics": {
            "type": "diattenuator_retarder_function",
            "properties": {"phi": 0, "epsilon": 0, "theta": 0},
        },
        "image_rotator": {
            "type": "general_retarder_function",
            "properties": {"phi": 0.5 * 2 * np.pi, "theta": 0, "delta_theta": 0},
        },
        "hwp": {
            "type": "general_retarder_function",
            "properties": {"phi": 0.5, "theta": 0, "delta_theta": 0},
        },
        "lp": {
            "type": "general_linear_polarizer_function_with_theta",
            "properties": {"theta": 0},
        },
    }
}

# Input paths and call plotting function
h5_filename = "675nm_no_IMR_offset_with_dichroic.h5"
txt_filename = "675-50nm.txt"
csv_file_path = "/home/rebeccaz/Github/vampires_calibration/data/20230914_processed_table.csv"

plotting.plot_mcmc_fits_double_diff_sum(
    h5_filename=h5_filename,
    txt_filename=txt_filename,
    csv_path=csv_file_path,
    filter_wavelength="675-50",
    system_dict=system_dict,
    wavelength_str="675nm",
    n_samples=50,
    step_range = all_step_range
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_729572/1920672173.py in <module>
#      51 csv_file_path = "/home/rebeccaz/Github/vampires_calibration/data/20230914_processed_table.csv"
#      52
# ---> 53 plotting.plot_mcmc_fits_double_diff_sum(
#      54     h5_filename=h5_filename,
#      55     txt_filename=txt_filename,
#
# ~/Github/vampires_calibration/plotting_rewrite.py in plot_mcmc_fits_double_diff_sum(h5_filename, txt_filename, csv_path, filter_wavelength, system_dict, wavelength_str, n_samples, step_range, imr_theta_filter)
#     141     if len(flat_chain) < n_samples:
#     142         raise ValueError(f"Only {len(flat_chain)} samples available, but {n_samples} requested.")
# --> 143     np.random.seed(42)
#     144     sample_indices = np.random.choice(flat_chain.shape[0], size=n_samples, replace=False)
#     145
#
# ~/Github/vampires_calibration/instruments_jax.py in model(p, system_parameters, system_mm, configuration_list, s_in, process_model)
#     442
#     443     # Update the system Mueller matrix with parameters that we're fitting
# --> 444     system_mm = update_system_mm(p, system_parameters, system_mm)
#     445
#     446     # Generate a model dataset
#
# ~/Github/vampires_calibration/instruments_jax.py in update_system_mm(parameter_values, system_parameters, system_mm)
#     175                 # print("system_mm system_mm.master_property_dict[component_name][parameter_name])
#     176                 # print("Parameter Value: " + str(parameter_values[i]))
# --> 177                 system_mm.master_property_dict[component_name][parameter_name] = parameter_values[i]
#     178                 # print(system_mm.evaluate())
#     179             elif parameter_name != "log_f":
#
# IndexError: index 11 is out of bounds for axis 0 with size 11
