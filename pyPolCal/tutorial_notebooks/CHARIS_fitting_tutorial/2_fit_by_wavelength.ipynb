# %% [markdown]
# # Fitting by Wavelength
# Here you will set offset angles to zero and fit every wavelength-dependent parameter. There are two ways of doing this: the first is following the instructions of this notebook, and the second is modifying the source code one of my wrapper functions in `instruments.py` with your system dictionary. The one I use is `fit_CHARIS_mueller_matrix_by_bin`. You can see examples of that workflow in `CHARIS/minimize`. Before fitting, feel free to plot whatever model you are building off to make sure the fitting function is actually minimizing. Instructions for that are available in `plotting_a_model.ipynb`.

# %% [markdown]
# # Step 1: Fit by Iterating Over All Bins
# The workflow will go like this: per each bin, you 1. read in all data using the `read_csv` function -> 2. initialize your model following instructions in `system_mueller_matrix_tutorial.ipynb` -> 3. set up a `p0_dict` with all parameters that you are fitting for (specifying what components they belong to) -> 4. set bounds for each parameter -> 5. minimize using `scipy.optimize.least_squares()` -> 6. plot the data and fitted model using the procedure laid out in `plotting_a_model.ipynb` -> 7. calculate $s_{rel}$, the relative polarimetric accuracy of your model using the procedure from the Van Holstein 2019 VLT SPHERE polcal -> 8. save the fitted parameters to a .txt file.

# %%
from pyPolCal.csv_tools import read_csv 
from pyPolCal.utils import * 
from pyPolCal.fitting import minimize_system_mueller_matrix, model, process_dataset, process_model, update_p0, update_system_mm
from pyPolCal.plotting import plot_data_and_model
from pyPolCal.constants import wavelength_bins # all CHARIS wavelength bins
from pyMuellerMat.physical_models.charis_physical_models import * # Joost 't Hart 2021 physical models
import numpy as np
import json
from importlib.resources import files

s_rels = []
errors = []
for bin in range(22): # 22 wavelength bins

    ############ PREPARING MODEL #############

    # Define the path to the CSV file for the current bin
    csvpath = f'bin{bin}.csv'
    csvdir = files('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs') / csvpath
     # Read csv
    interleaved_values, interleaved_stds, configuration_list = read_csv(csvdir)
    
    # Load in system dictionary

    system_dict = {
        "components" : {
            "wollaston" : {
            "type" : "wollaston_prism_function",
            "properties" : {"beam": 'o'}, 
            "tag": "internal",
            },

            "nbs_rot": {
                "type": "rotator_function",
                "properties": {"pa": 0},
                "tag": "internal",
            },
            "image_rotator" : {
            "type" : "elliptical_retarder_function",
            "properties" : {"delta_theta":0}, # Theta (rotation angle) will be updated by config list
            "tag": "internal",
            },
            
            "hwp" : {
                "type" : "general_retarder_function",
                "properties" : {"delta_theta": 0}, # Theta (rotation angle) will be updated by config list
                "tag": "internal",
            },


            "lp" :{
                "type" : "diattenuator_retarder_function",
                "properties" : {"epsilon": 1, "delta_theta":0}, # Perfect calibration polarizer
                "tag": "internal",
            },
    }
    }

    # Converting system dictionary into system Mueller Matrix object
    system_mm = generate_system_mueller_matrix(system_dict)

    ############ FITTING #############

    # Starting guesses for all parameters, I'm taking mine from the Joost't Hart 2021 physical models
    hwp_retardance = HWP_retardance(wavelength_bins)[bin]
    imr_retardance = IMR_retardance(wavelength_bins)[bin]
    wol_eta = 1 # imperfect wollaston fit, using perfect as starting guess

    # p0 dictionary assigning parameters to their components in the system dictionary
    p0 = {
        "image_rotator": {"phi_h":imr_retardance, "phi_r":0, "phi_45":0}, # linear retarder for starting guess
        'hwp': {"phi":hwp_retardance},
        'wollaston': {'eta': wol_eta}
    }
    print(p0)

    # Set bounds for each component in order they appear in p0 dictionary
    retardance_bounds = (0,2*np.pi) 
    eta_bounds = (0,1)
    bounds_list = [retardance_bounds, retardance_bounds, retardance_bounds, retardance_bounds, eta_bounds]

    # Minimize, using process dataset and process model to process everything into double differences
    # Excluding double sums (always do this for CHARIS)
    # Not using aperture errors, works well for our large apertures

    result, new_logl, error = minimize_system_mueller_matrix(p0, system_mm, interleaved_values, 
    configuration_list, process_dataset=process_dataset,process_model=process_model,include_sums=False, bounds = bounds_list,mode='least_squares')
    print(result)
    errors.append(error)

    ########## PLOTTING RESULTS ##########

    # Update p0 and system mueller matrix with fits
    update_p0(p0, result.x)
    print(p0)
    p0_values, p0_keywords = parse_configuration(p0) # parsing updated p0 dictionary
    updated_system_mm = update_system_mm(p0_values, p0_keywords, system_mm)

    # Plot using instructions in plotting_a_model.ipynb
    interleaved_modeled = model(p0_values, p0_keywords, updated_system_mm, configuration_list, 
                                process_model=process_model,s_in=[1,0,0,0])

    # Inputting wavelength to use wavelength as the title
    plot_data_and_model(interleaved_values, interleaved_modeled, configuration_list, 
                                    wavelength=wavelength_bins[bin], include_sums=False)

    ########## CALCULATE S_REL ############

    # Processing single diffs/sums into double diffs/sums
    data_dd = process_dataset(interleaved_values)[::2] # only taking diffs

    # Only taking diffs                                              
    model_dd = interleaved_modeled[::2]

    # Converting resiudals to a percent
    residuals = data_dd*100 - model_dd*100

    # Calculating s_rel
    s_rel = np.sqrt(np.sum(residuals**2)/(len(data_dd)-len(p0_values)))
    s_rels.append(s_rel)


    ######### SAVING MODEL ###########

    updated_p0_path = f'wavelength_fit_results/bin{bin}.json'
    with open (updated_p0_path, 'w') as f:
        json.dump(p0, f, indent=4)
# Out:
# {'image_rotator': {'phi_h': np.float64(4.530154810514752), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.001856927823014)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0844e-01                                    5.30e+00
#        1              2         1.2900e-02      9.55e-02       1.79e-01       2.78e-01
#        2              3         1.2512e-02      3.88e-04       1.44e-02       1.94e-03
#        3              4         1.2511e-02      1.46e-06       1.45e-03       1.34e-05
#        4              5         1.2511e-02      4.10e-11       7.76e-06       6.18e-07
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 1.0844e-01, final cost 1.2511e-02, first-order optimality 6.18e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-9.524e-03 -1.681e-02 ...  1.305e-02 -1.166e-02]
#            x: [ 4.388e+00  4.686e-22  9.933e-02  3.036e+00  1.000e+00]
#         cost: 0.012510579092010594
#          jac: [[-9.278e-01 -3.595e-04 ... -4.546e-01  3.660e-01]
#                [-1.945e-02  3.595e-04 ...  4.546e-01 -4.927e-02]
#                ...
#                [ 7.137e-01  1.529e-01 ... -2.695e-01 -2.527e-01]
#                [ 1.922e-02  1.340e-03 ... -6.312e-01  6.629e-02]]
#         grad: [-2.379e-09  1.148e-01 -9.988e-08 -8.208e-09 -9.410e-02]
#   optimality: 6.176165078925949e-07
#  active_mask: [ 0 -1  0  0  1]
#         nfev: 5
#         njev: 5
# {'image_rotator': {'phi_h': np.float64(4.388230834152767), 'phi_r': np.float64(4.685504106986878e-22), 'phi_45': np.float64(0.09932607997490761)}, 'hwp': {'phi': np.float64(3.035576477659275)}, 'wollaston': {'eta': np.float64(0.9999999999999999)}}
# {'image_rotator': {'phi_h': np.float64(4.298515181117285), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9908432015864457)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3447e-01                                    5.33e+00
#        1              2         1.2117e-02      1.22e-01       2.04e-01       4.24e-01
#        2              3         1.0760e-02      1.36e-03       2.70e-02       1.23e-02
#        3              4         1.0757e-02      2.33e-06       1.29e-03       1.49e-04
#        4              5         1.0757e-02      2.81e-10       1.09e-05       2.73e-06
#        5              6         1.0757e-02      8.21e-14       1.73e-07       4.63e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.3447e-01, final cost 1.0757e-02, first-order optimality 4.63e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 4.203e-04  4.667e-03 ...  1.803e-02  7.453e-03]
#            x: [ 4.115e+00  8.576e-28  1.110e-01  3.013e+00  9.905e-01]
#         cost: 0.010757333509830989
#          jac: [[-7.793e-01 -6.497e-04 ... -3.707e-01  6.110e-01]
#                [-3.901e-02  6.497e-04 ...  3.707e-01 -5.072e-02]
#                ...
#                [ 6.227e-01  1.410e-01 ... -2.487e-01 -4.288e-01]
#                [ 4.307e-02  1.897e-03 ... -5.654e-01  7.148e-02]]
#         grad: [-1.451e-09  9.506e-02  7.601e-09  1.537e-08  2.974e-10]
#   optimality: 4.630711345384171e-08
#  active_mask: [ 0 -1  0  0  0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(4.114816462325635), 'phi_r': np.float64(8.575660914566299e-28), 'phi_45': np.float64(0.11099405622623305)}, 'hwp': {'phi': np.float64(3.0130260663297723)}, 'wollaston': {'eta': np.float64(0.9905250558208459)}}
# {'image_rotator': {'phi_h': np.float64(4.016290856949604), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9802180654142774)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.0478e-02                                    2.25e+00
#        1              2         5.1108e-03      5.54e-02       1.55e-01       1.79e-01
#        2              3         4.8181e-03      2.93e-04       1.16e-02       3.46e-02
#        3              4         4.7343e-03      8.38e-05       6.89e-03       6.36e-04
#        4              5         4.7343e-03      7.03e-09       8.04e-05       7.39e-06
#        5              6         4.7343e-03      8.32e-13       6.89e-07       1.41e-07
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 6.0478e-02, final cost 4.7343e-03, first-order optimality 1.41e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 3.534e-03 -3.512e-03 ...  1.536e-02 -1.178e-03]
#            x: [ 3.909e+00  2.984e-25  1.119e-01  3.023e+00  9.952e-01]
#         cost: 0.004734328966519282
#          jac: [[-6.456e-01 -7.387e-04 ... -3.012e-01  7.560e-01]
#                [-4.458e-02  7.387e-04 ...  3.012e-01 -3.848e-02]
#                ...
#                [ 5.292e-01  1.255e-01 ... -2.193e-01 -5.511e-01]
#                [ 5.258e-02  1.976e-03 ... -4.899e-01  5.596e-02]]
#         grad: [ 3.720e-09  5.538e-02  1.759e-08  4.648e-08  4.953e-10]
#   optimality: 1.4053315483607875e-07
#  active_mask: [ 0 -1  0  0  0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(3.9085787298004853), 'phi_r': np.float64(2.984153922079929e-25), 'phi_45': np.float64(0.11190631716032358)}, 'hwp': {'phi': np.float64(3.0233563438707134)}, 'wollaston': {'eta': np.float64(0.9952107594732644)}}
# {'image_rotator': {'phi_h': np.float64(3.6959844091398195), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.97033706726214)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.6571e-02                                    3.28e+00
#        1              2         3.7657e-03      4.28e-02       1.39e-01       8.29e-02
#        2              3         3.5204e-03      2.45e-04       1.07e-02       2.76e-03
#        3              4         3.5153e-03      5.05e-06       2.32e-03       2.08e-04
#        4              5         3.5153e-03      2.36e-08       1.67e-04       1.62e-05
#        5              6         3.5153e-03      8.83e-12       3.51e-06       7.22e-07
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 4.6571e-02, final cost 3.5153e-03, first-order optimality 7.22e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 4.326e-03 -2.689e-03 ...  7.100e-03 -1.130e-04]
#            x: [ 3.671e+00  1.136e-23  1.181e-01  3.050e+00  9.846e-01]
#         cost: 0.0035152967076379307
#          jac: [[-4.573e-01 -7.377e-04 ... -2.095e-01  8.815e-01]
#                [-4.001e-02  7.377e-04 ...  2.095e-01 -2.146e-02]
#                ...
#                [ 3.813e-01  9.656e-02 ... -1.649e-01 -6.639e-01]
#                [ 4.978e-02  1.650e-03 ... -3.629e-01  3.219e-02]]
#         grad: [-3.090e-08  2.669e-02 -5.906e-08 -2.234e-07  6.000e-10]
#   optimality: 7.223031983125406e-07
#  active_mask: [ 0 -1  0  0  0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(3.671258013084939), 'phi_r': np.float64(1.1356408261032882e-23), 'phi_45': np.float64(0.11812312306186086)}, 'hwp': {'phi': np.float64(3.0495748145338992)}, 'wollaston': {'eta': np.float64(0.98463619059107)}}
# {'image_rotator': {'phi_h': np.float64(3.361467081420097), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9615265218152054)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.0323e-02                                    4.11e+00
#        1              2         7.0141e-03      5.33e-02       2.00e-01       1.76e-01
#        2              3         5.0712e-03      1.94e-03       7.77e-02       2.55e-02
#        3              4         4.8495e-03      2.22e-04       9.77e-03       8.08e-04
#        4              5         4.8287e-03      2.08e-05       6.26e-03       2.09e-04
#        5              6         4.8284e-03      3.33e-07       8.17e-04       1.42e-05
#        6              7         4.8284e-03      1.62e-10       1.88e-05       1.34e-06
#        7              8         4.8284e-03      9.84e-14       4.29e-07       1.15e-07
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 6.0323e-02, final cost 4.8284e-03, first-order optimality 1.15e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 9.264e-04  1.191e-03 ...  2.422e-03  1.684e-03]
#            x: [ 3.494e+00  2.700e-29  1.169e-01  3.148e+00  9.852e-01]
#         cost: 0.004828353931302212
#          jac: [[-3.430e-01  6.214e-05 ... -1.739e-01  9.346e-01]
#                [ 3.135e-03 -6.214e-05 ...  1.739e-01  1.189e-03]
#                ...
#                [ 2.406e-01  6.905e-02 ... -8.986e-02 -7.335e-01]
#                [-4.101e-03 -1.306e-04 ... -2.197e-01 -1.528e-03]]
#         grad: [-9.742e-10  3.225e-03  9.819e-09  3.653e-08 -8.994e-11]
#   optimality: 1.1500368232481105e-07
#  active_mask: [ 0 -1  0  0  0]
#         nfev: 8
#         njev: 8
# {'image_rotator': {'phi_h': np.float64(3.4937741979746058), 'phi_r': np.float64(2.699874122520889e-29), 'phi_45': np.float64(0.11690448470240537)}, 'hwp': {'phi': np.float64(3.1483936841022158)}, 'wollaston': {'eta': np.float64(0.9852048250487618)}}
# {'image_rotator': {'phi_h': np.float64(3.007361431522309), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9540877809862343)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.3236e-02                                    4.41e+00
#        1              2         7.8730e-03      8.54e-02       2.95e-01       1.02e-01
#        2              3         5.0104e-03      2.86e-03       2.68e-02       3.14e-03
#        3              4         4.3477e-03      6.63e-04       2.01e-02       2.37e-03
#        4              5         4.2474e-03      1.00e-04       8.53e-03       4.08e-04
#        5              6         4.2399e-03      7.43e-06       2.79e-03       1.25e-04
#        6              7         4.2398e-03      9.76e-08       3.68e-04       2.00e-05
#        7              8         4.2398e-03      6.11e-11       1.20e-05       1.07e-06
#        8              9         4.2398e-03      5.79e-14       3.68e-07       4.47e-08
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 9.3236e-02, final cost 4.2398e-03, first-order optimality 4.47e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.595e-03  9.209e-03 ...  9.804e-04  8.623e-03]
#            x: [ 2.683e+00  6.758e-26  8.751e-02  2.987e+00  9.899e-01]
#         cost: 0.004239824947320036
#          jac: [[ 5.032e-01 -1.756e-03 ...  2.839e-01  8.561e-01]
#                [-6.569e-02  1.756e-03 ... -2.839e-01  3.929e-02]
#                ...
#                [-2.999e-01 -1.128e-01 ...  6.297e-02 -7.179e-01]
#                [ 9.178e-02  3.845e-03 ...  2.135e-01 -3.900e-02]]
#         grad: [ 2.781e-09  1.094e-02  5.501e-09 -1.358e-08 -6.108e-10]
#   optimality: 4.4747752739847914e-08
#  active_mask: [ 0 -1  0  0  0]
#         nfev: 9
#         njev: 9
# {'image_rotator': {'phi_h': np.float64(2.6832056000315023), 'phi_r': np.float64(6.75793859750568e-26), 'phi_45': np.float64(0.0875142427285785)}, 'hwp': {'phi': np.float64(2.987004972858117)}, 'wollaston': {'eta': np.float64(0.989891033195686)}}
# {'image_rotator': {'phi_h': np.float64(2.658791656657683), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9483013148482353)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0382e-01                                    4.46e+00
#        1              2         2.4947e-03      1.01e-01       2.14e-01       1.29e-01
#        2              3         2.0052e-03      4.89e-04       1.07e-02       1.51e-03
#        3              4         1.9479e-03      5.73e-05       5.36e-03       1.05e-03
#        4              5         1.9459e-03      1.96e-06       1.07e-03       2.17e-04
#        5              6         1.9459e-03      4.93e-09       5.72e-05       1.15e-05
#        6              7         1.9459e-03      2.75e-12       1.88e-06       5.70e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.0382e-01, final cost 1.9459e-03, first-order optimality 5.70e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-6.108e-03  5.638e-03 ... -1.031e-03  6.649e-03]
#            x: [ 2.457e+00  2.881e-02  8.575e-02  2.953e+00  9.862e-01]
#         cost: 0.0019458935913768943
#          jac: [[ 6.889e-01  6.029e-03 ...  3.772e-01  7.076e-01]
#                [-6.603e-02  1.274e-03 ... -3.772e-01  6.596e-02]
#                ...
#                [-4.259e-01 -1.796e-01 ...  1.080e-01 -6.424e-01]
#                [ 9.894e-02  6.084e-03 ...  3.269e-01 -7.014e-02]]
#         grad: [ 4.215e-08 -9.111e-08  2.135e-08 -1.659e-07 -1.006e-11]
#   optimality: 5.698071098195815e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(2.457015344508113), 'phi_r': np.float64(0.028807987033153706), 'phi_45': np.float64(0.08574514750830745)}, 'hwp': {'phi': np.float64(2.95321080938416)}, 'wollaston': {'eta': np.float64(0.9862018898984535)}}
# {'image_rotator': {'phi_h': np.float64(2.329506952088865), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9444303373174208)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.5367e-02                                    3.76e+00
#        1              2         2.3400e-03      9.30e-02       1.71e-01       1.74e-01
#        2              3         1.9306e-03      4.09e-04       1.44e-02       2.39e-03
#        3              4         1.9204e-03      1.03e-05       1.92e-03       1.89e-04
#        4              5         1.9203e-03      1.01e-07       1.98e-04       2.29e-05
#        5              6         1.9203e-03      1.75e-11       2.69e-06       3.69e-07
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 9.5367e-02, final cost 1.9203e-03, first-order optimality 3.69e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-8.654e-03  6.830e-03 ... -5.170e-03  8.725e-03]
#            x: [ 2.179e+00  5.415e-02  7.627e-02  2.952e+00  9.869e-01]
#         cost: 0.0019202735580496038
#          jac: [[ 8.549e-01  1.977e-02 ...  4.506e-01  4.885e-01]
#                [-4.592e-02  3.368e-04 ... -4.506e-01  8.243e-02]
#                ...
#                [-5.648e-01 -2.700e-01 ...  1.700e-01 -5.118e-01]
#                [ 7.678e-02  7.615e-03 ...  4.640e-01 -9.542e-02]]
#         grad: [ 2.895e-08 -3.172e-08 -5.949e-09 -1.109e-07 -2.150e-09]
#   optimality: 3.693761230662977e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(2.178728721575806), 'phi_r': np.float64(0.05414960005680333), 'phi_45': np.float64(0.07627444372845449)}, 'hwp': {'phi': np.float64(2.951963252206529)}, 'wollaston': {'eta': np.float64(0.9869009667216331)}}
# {'image_rotator': {'phi_h': np.float64(2.0376892427031716), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9427243097474256)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.4493e-02                                    2.88e+00
#        1              2         1.9143e-03      6.26e-02       1.34e-01       1.40e-01
#        2              3         1.6450e-03      2.69e-04       1.01e-02       1.43e-03
#        3              4         1.6432e-03      1.76e-06       7.16e-04       3.83e-05
#        4              5         1.6432e-03      3.84e-09       3.46e-05       2.48e-06
#        5              6         1.6432e-03      4.14e-14       1.28e-07       2.32e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 6.4493e-02, final cost 1.6432e-03, first-order optimality 2.32e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-1.087e-02  6.211e-03 ... -7.363e-03  8.071e-03]
#            x: [ 1.936e+00  6.583e-02  6.550e-02  2.948e+00  9.868e-01]
#         cost: 0.0016432168585921274
#          jac: [[ 9.458e-01  3.147e-02 ...  4.861e-01  2.643e-01]
#                [-2.536e-02 -1.665e-04 ... -4.861e-01  9.319e-02]
#                ...
#                [-6.533e-01 -3.502e-01 ...  2.126e-01 -3.701e-01]
#                [ 5.315e-02  8.470e-03 ...  5.539e-01 -1.135e-01]]
#         grad: [ 1.347e-09  1.444e-11 -9.888e-11 -6.944e-09 -1.377e-10]
#   optimality: 2.3158308488890285e-08
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.9358596505470933), 'phi_r': np.float64(0.06582948885797098), 'phi_45': np.float64(0.06549567798161429)}, 'hwp': {'phi': np.float64(2.9479495964304427)}, 'wollaston': {'eta': np.float64(0.9867847744601573)}}
# {'image_rotator': {'phi_h': np.float64(1.7689132118012587), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.943422236996289)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.5911e-02                                    2.28e+00
#        1              2         7.3589e-04      3.52e-02       1.10e-01       7.89e-02
#        2              3         6.2106e-04      1.15e-04       5.66e-03       2.46e-04
#        3              4         6.1943e-04      1.63e-06       6.53e-04       6.35e-06
#        4              5         6.1942e-04      3.79e-09       3.30e-05       2.92e-07
#        5              6         6.1942e-04      2.57e-14       8.71e-08       2.19e-09
# `gtol` termination condition is satisfied.
# Function evaluations 6, initial cost 3.5911e-02, final cost 6.1942e-04, first-order optimality 2.19e-09.
#      message: `gtol` termination condition is satisfied.
#      success: True
#       status: 1
#          fun: [-1.207e-02 -2.321e-03 ... -9.641e-03  1.126e-03]
#            x: [ 1.721e+00  7.978e-02  6.034e-02  2.952e+00  9.873e-01]
#         cost: 0.0006194213356366899
#          jac: [[ 9.798e-01  4.571e-02 ...  4.933e-01  5.705e-02]
#                [-5.318e-03 -5.401e-04 ... -4.933e-01  9.437e-02]
#                ...
#                [-6.999e-01 -4.232e-01 ...  2.412e-01 -2.290e-01]
#                [ 2.734e-02  8.700e-03 ...  6.088e-01 -1.195e-01]]
#         grad: [-1.566e-10 -3.465e-10 -3.521e-10 -4.912e-10 -1.891e-11]
#   optimality: 2.1909579424314064e-09
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.7213223617664088), 'phi_r': np.float64(0.07978113437850277), 'phi_45': np.float64(0.06034132244342228)}, 'hwp': {'phi': np.float64(2.9522635371631933)}, 'wollaston': {'eta': np.float64(0.9873384845744447)}}
# {'image_rotator': {'phi_h': np.float64(1.5364262782470774), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.94675578039066)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.3540e-02                                    3.24e+00
#        1              2         2.5125e-03      3.10e-02       1.02e-01       6.54e-02
#        2              3         2.4112e-03      1.01e-04       4.88e-03       4.95e-04
#        3              4         2.4092e-03      2.04e-06       7.21e-04       4.44e-05
#        4              5         2.4092e-03      5.02e-09       3.75e-05       2.42e-06
#        5              6         2.4092e-03      7.06e-14       1.37e-07       4.14e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 3.3540e-02, final cost 2.4092e-03, first-order optimality 4.14e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-1.260e-02  1.122e-02 ... -8.860e-03  1.267e-02]
#            x: [ 1.518e+00  8.358e-02  5.690e-02  2.959e+00  9.863e-01]
#         cost: 0.0024091730887497356
#          jac: [[ 9.706e-01  5.457e-02 ...  4.797e-01 -1.407e-01]
#                [ 1.276e-02 -4.397e-04 ... -4.797e-01  9.017e-02]
#                ...
#                [-7.156e-01 -4.871e-01 ...  2.576e-01 -8.415e-02]
#                [ 2.575e-03  7.967e-03 ...  6.341e-01 -1.182e-01]]
#         grad: [-1.263e-09 -3.496e-09  4.678e-09 -1.245e-08  7.706e-10]
#   optimality: 4.138012422132618e-08
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.5181955216610905), 'phi_r': np.float64(0.08358190185374303), 'phi_45': np.float64(0.056902641213250484)}, 'hwp': {'phi': np.float64(2.9591277497282085)}, 'wollaston': {'eta': np.float64(0.986342944825226)}}
# {'image_rotator': {'phi_h': np.float64(1.337879684752699), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9529523030518745)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.8438e-02                                    4.09e+00
#        1              2         3.1126e-03      3.53e-02       1.00e-01       1.57e-01
#        2              3         3.0008e-03      1.12e-04       4.77e-03       9.26e-04
#        3              4         2.9989e-03      1.90e-06       7.18e-04       5.30e-05
#        4              5         2.9989e-03      4.21e-09       3.52e-05       2.76e-06
#        5              6         2.9989e-03      1.13e-13       1.77e-07       8.13e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 3.8438e-02, final cost 2.9989e-03, first-order optimality 8.13e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-1.325e-02  1.302e-02 ... -8.819e-03  1.458e-02]
#            x: [ 1.354e+00  8.492e-02  5.086e-02  2.968e+00  9.860e-01]
#         cost: 0.0029989149479398183
#          jac: [[ 9.361e-01  6.068e-02 ...  4.562e-01 -2.950e-01]
#                [ 2.536e-02 -3.971e-04 ... -4.562e-01  8.263e-02]
#                ...
#                [-7.076e-01 -5.359e-01 ...  2.622e-01  3.400e-02]
#                [-1.604e-02  7.171e-03 ...  6.348e-01 -1.111e-01]]
#         grad: [-4.392e-09 -7.919e-09  1.015e-08 -2.453e-08 -3.651e-10]
#   optimality: 8.131771867301167e-08
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.3543163470497535), 'phi_r': np.float64(0.0849172502838437), 'phi_45': np.float64(0.05086225133218234)}, 'hwp': {'phi': np.float64(2.9682601353359708)}, 'wollaston': {'eta': np.float64(0.9860396902879555)}}
# {'image_rotator': {'phi_h': np.float64(1.1782478110981653), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.962237827816352)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.6242e-02                                    4.97e+00
#        1              2         6.9523e-04      5.55e-02       1.17e-01       2.61e-01
#        2              3         5.2456e-04      1.71e-04       5.61e-03       2.90e-04
#        3              4         5.2144e-04      3.12e-06       9.23e-04       1.05e-05
#        4              5         5.2142e-04      1.48e-08       6.79e-05       8.88e-07
#        5              6         5.2142e-04      4.56e-13       3.82e-07       1.20e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 5.6242e-02, final cost 5.2142e-04, first-order optimality 1.20e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-1.130e-02  2.507e-03 ... -7.468e-03  5.013e-03]
#            x: [ 1.238e+00  8.890e-02  4.662e-02  2.983e+00  9.883e-01]
#         cost: 0.0005214233985909159
#          jac: [[ 9.013e-01  6.739e-02 ...  4.359e-01 -3.963e-01]
#                [ 3.124e-02 -4.299e-04 ... -4.359e-01  7.262e-02]
#                ...
#                [-6.905e-01 -5.718e-01 ...  2.607e-01  1.167e-01]
#                [-2.681e-02  6.362e-03 ...  6.249e-01 -9.909e-02]]
#         grad: [-6.976e-10 -1.001e-09  2.583e-09 -3.624e-09  1.170e-10]
#   optimality: 1.195839670304532e-08
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.238144822946136), 'phi_r': np.float64(0.08890221806898682), 'phi_45': np.float64(0.046620381828618315)}, 'hwp': {'phi': np.float64(2.982967910809615)}, 'wollaston': {'eta': np.float64(0.9882909044536583)}}
# {'image_rotator': {'phi_h': np.float64(1.0458778179531958), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9748400845824543)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.6367e-02                                    5.79e+00
#        1              2         7.4402e-04      8.56e-02       1.44e-01       3.78e-01
#        2              3         4.4768e-04      2.96e-04       7.39e-03       4.11e-04
#        3              4         4.4325e-04      4.44e-06       1.13e-03       2.95e-05
#        4              5         4.4322e-04      2.34e-08       8.82e-05       2.98e-06
#        5              6         4.4322e-04      8.81e-13       5.46e-07       1.58e-08
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 8.6367e-02, final cost 4.4322e-04, first-order optimality 1.58e-08.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-8.092e-03 -1.853e-03 ... -7.109e-03 -1.689e-05]
#            x: [ 1.145e+00  9.352e-02  4.592e-02  2.996e+00  9.869e-01]
#         cost: 0.00044322233347943884
#          jac: [[ 8.631e-01  7.364e-02 ...  4.154e-01 -4.733e-01]
#                [ 3.422e-02 -3.775e-04 ... -4.154e-01  6.398e-02]
#                ...
#                [-6.663e-01 -5.982e-01 ...  2.551e-01  1.809e-01]
#                [-3.323e-02  5.570e-03 ...  6.076e-01 -8.817e-02]]
#         grad: [-2.018e-10  7.073e-11 -2.528e-09 -2.201e-09 -4.289e-10]
#   optimality: 1.5765506485134357e-08
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.1453348696412564), 'phi_r': np.float64(0.0935176434651679), 'phi_45': np.float64(0.045916204750700705)}, 'hwp': {'phi': np.float64(2.9958536480511175)}, 'wollaston': {'eta': np.float64(0.9869000576525357)}}
# {'image_rotator': {'phi_h': np.float64(0.9411728208731114), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9909913816183407)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0843e-01                                    6.28e+00
#        1              2         6.7881e-03      1.02e-01       1.62e-01       4.12e-01
#        2              3         6.3593e-03      4.29e-04       9.12e-03       1.62e-03
#        3              4         6.3514e-03      7.92e-06       1.56e-03       2.93e-04
#        4              5         6.3513e-03      7.36e-08       1.59e-04       1.62e-05
#        5              6         6.3513e-03      1.14e-11       2.17e-06       6.63e-07
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.0843e-01, final cost 6.3513e-03, first-order optimality 6.63e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-5.440e-03 -1.827e-02 ... -8.342e-03 -1.492e-02]
#            x: [ 1.064e+00  9.328e-02  3.927e-02  3.021e+00  9.879e-01]
#         cost: 0.006351309963630276
#          jac: [[ 8.300e-01  7.602e-02 ...  3.999e-01 -5.332e-01]
#                [ 3.194e-02 -4.166e-04 ... -3.999e-01  5.088e-02]
#                ...
#                [-6.422e-01 -6.204e-01 ...  2.468e-01  2.397e-01]
#                [-3.406e-02  4.450e-03 ...  5.859e-01 -7.017e-02]]
#         grad: [-1.494e-09  3.338e-08 -1.062e-07 -3.354e-08 -1.026e-10]
#   optimality: 6.630806626745572e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.0635329824359134), 'phi_r': np.float64(0.09328497868056966), 'phi_45': np.float64(0.039274862259331855)}, 'hwp': {'phi': np.float64(3.020882080426653)}, 'wollaston': {'eta': np.float64(0.9878597498692225)}}
# {'image_rotator': {'phi_h': np.float64(0.8612584400689047), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0109318293578498)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3279e-01                                    6.39e+00
#        1              2         1.1856e-02      1.21e-01       1.85e-01       4.43e-01
#        2              3         1.1199e-02      6.57e-04       1.21e-02       5.49e-03
#        3              4         1.1187e-02      1.17e-05       1.97e-03       8.44e-04
#        4              5         1.1187e-02      1.28e-07       2.10e-04       3.51e-05
#        5              6         1.1187e-02      4.04e-11       4.16e-06       3.60e-06
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.3279e-01, final cost 1.1187e-02, first-order optimality 3.60e-06.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-6.838e-03 -2.522e-02 ... -8.103e-03 -2.194e-02]
#            x: [ 1.013e+00  9.010e-02  3.548e-02  3.044e+00  9.874e-01]
#         cost: 0.011187223453998842
#          jac: [[ 8.088e-01  7.476e-02 ...  3.915e-01 -5.663e-01]
#                [ 2.739e-02 -3.588e-04 ... -3.915e-01  4.006e-02]
#                ...
#                [-6.236e-01 -6.316e-01 ...  2.389e-01  2.790e-01]
#                [-3.083e-02  3.418e-03 ...  5.672e-01 -5.496e-02]]
#         grad: [ 1.070e-07  2.593e-07 -5.755e-07  7.869e-07 -3.860e-09]
#   optimality: 3.5954926820447933e-06
#  active_mask: [0 0 0 0 0]
#         nfev: 6
#         njev: 6
# {'image_rotator': {'phi_h': np.float64(1.012701180884497), 'phi_r': np.float64(0.0901040496667988), 'phi_45': np.float64(0.03547562613374403)}, 'hwp': {'phi': np.float64(3.044036325748185)}, 'wollaston': {'eta': np.float64(0.9873558723641623)}}
# {'image_rotator': {'phi_h': np.float64(0.8030305075769144), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0349124963396106)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.6232e-01                                    6.70e+00
#        1              2         1.4953e-02      1.47e-01       2.16e-01       4.89e-01
#        2              3         1.3916e-02      1.04e-03       1.57e-02       8.10e-03
#        3              4         1.3886e-02      2.91e-05       2.92e-03       1.41e-03
#        4              5         1.3886e-02      8.93e-07       5.60e-04       5.68e-05
#        5              6         1.3886e-02      1.86e-09       2.77e-05       1.08e-05
#        6              7         1.3886e-02      5.68e-13       5.14e-07       6.84e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.6232e-01, final cost 1.3886e-02, first-order optimality 6.84e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-5.709e-03 -2.866e-02 ... -5.392e-03 -2.587e-02]
#            x: [ 9.859e-01  9.128e-02  3.890e-02  3.068e+00  9.899e-01]
#         cost: 0.013885572895905026
#          jac: [[ 8.029e-01  7.653e-02 ...  3.918e-01 -5.785e-01]
#                [ 2.105e-02 -2.332e-04 ... -3.918e-01  2.978e-02]
#                ...
#                [-6.112e-01 -6.411e-01 ...  2.333e-01  3.017e-01]
#                [-2.467e-02  2.413e-03 ...  5.552e-01 -4.042e-02]]
#         grad: [-2.171e-08 -3.393e-08  6.326e-08 -2.128e-07 -5.367e-10]
#   optimality: 6.840877288235425e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9858559547480904), 'phi_r': np.float64(0.0912820839644178), 'phi_45': np.float64(0.03890311907933286)}, 'hwp': {'phi': np.float64(3.0683461635874347)}, 'wollaston': {'eta': np.float64(0.989881116464863)}}
# {'image_rotator': {'phi_h': np.float64(0.7635782257098833), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0631989509178603)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.8009e-01                                    6.78e+00
#        1              2         1.4345e-02      1.66e-01       2.34e-01       5.30e-01
#        2              3         1.3142e-02      1.20e-03       1.69e-02       6.62e-03
#        3              4         1.3113e-02      2.84e-05       3.00e-03       1.32e-03
#        4              5         1.3113e-02      5.95e-07       4.72e-04       5.93e-05
#        5              6         1.3113e-02      5.31e-10       1.50e-05       6.42e-06
#        6              7         1.3113e-02      3.71e-13       3.81e-07       5.49e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.8009e-01, final cost 1.3113e-02, first-order optimality 5.49e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-5.726e-03 -2.679e-02 ... -3.879e-03 -2.551e-02]
#            x: [ 9.647e-01  9.079e-02  4.353e-02  3.098e+00  9.867e-01]
#         cost: 0.013112599715248538
#          jac: [[ 7.969e-01  7.629e-02 ...  3.929e-01 -5.841e-01]
#                [ 1.272e-02 -1.031e-04 ... -3.929e-01  1.781e-02]
#                ...
#                [-5.961e-01 -6.444e-01 ...  2.256e-01  3.230e-01]
#                [-1.554e-02  1.322e-03 ...  5.395e-01 -2.380e-02]]
#         grad: [-1.215e-08 -4.237e-08  8.397e-08 -1.722e-07  2.342e-09]
#   optimality: 5.486607470673434e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9646741294170863), 'phi_r': np.float64(0.09078699272042362), 'phi_45': np.float64(0.04352810143972898)}, 'hwp': {'phi': np.float64(3.09759444499961)}, 'wollaston': {'eta': np.float64(0.9866667225714829)}}
# {'image_rotator': {'phi_h': np.float64(0.740037727221333), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0960747250300913)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.9969e-01                                    6.78e+00
#        1              2         1.7139e-02      1.83e-01       2.53e-01       5.41e-01
#        2              3         1.5713e-02      1.43e-03       1.83e-02       7.23e-03
#        3              4         1.5670e-02      4.25e-05       3.56e-03       1.52e-03
#        4              5         1.5669e-02      1.32e-06       7.04e-04       7.92e-05
#        5              6         1.5669e-02      2.64e-09       3.32e-05       9.77e-06
#        6              7         1.5669e-02      8.15e-13       5.42e-07       7.85e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.9969e-01, final cost 1.5669e-02, first-order optimality 7.85e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.988e-03 -2.833e-02 ... -1.148e-03 -2.912e-02]
#            x: [ 9.585e-01  8.977e-02  4.983e-02  3.133e+00  9.875e-01]
#         cost: 0.015668875158906612
#          jac: [[ 8.044e-01  7.557e-02 ...  4.019e-01 -5.749e-01]
#                [ 2.435e-03 -1.165e-05 ... -4.019e-01  3.492e-03]
#                ...
#                [-5.878e-01 -6.465e-01 ...  2.195e-01  3.370e-01]
#                [-3.112e-03  2.320e-04 ...  5.288e-01 -4.571e-03]]
#         grad: [-9.859e-09 -8.160e-08  1.618e-07 -2.490e-07  5.346e-10]
#   optimality: 7.845347111229352e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9584982287487449), 'phi_r': np.float64(0.0897678179723653), 'phi_45': np.float64(0.049832235648241935)}, 'hwp': {'phi': np.float64(3.1330381248883867)}, 'wollaston': {'eta': np.float64(0.9875198753973636)}}
# {'image_rotator': {'phi_h': np.float64(0.7275457894546419), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.133845633636237)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.2449e-01                                    6.54e+00
#        1              2         1.8189e-02      2.06e-01       2.69e-01       5.75e-01
#        2              3         1.6804e-02      1.38e-03       1.78e-02       4.62e-03
#        3              4         1.6772e-02      3.19e-05       3.40e-03       1.27e-03
#        4              5         1.6772e-02      4.28e-07       4.24e-04       8.63e-05
#        5              6         1.6772e-02      3.05e-10       1.30e-05       9.10e-06
#        6              7         1.6772e-02      9.11e-13       6.67e-07       5.72e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.2449e-01, final cost 1.6772e-02, first-order optimality 5.72e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.874e-03 -2.894e-02 ...  1.437e-03 -3.125e-02]
#            x: [ 9.633e-01  8.687e-02  5.485e-02  3.168e+00  9.818e-01]
#         cost: 0.016771588319281133
#          jac: [[ 8.121e-01  7.257e-02 ...  4.107e-01 -5.567e-01]
#                [-7.280e-03  1.342e-05 ... -4.107e-01 -1.101e-02]
#                ...
#                [-5.806e-01 -6.404e-01 ...  2.132e-01  3.451e-01]
#                [ 9.727e-03 -6.504e-04 ...  5.179e-01  1.412e-02]]
#         grad: [-8.306e-09 -9.225e-08  1.789e-07 -1.015e-07 -1.063e-09]
#   optimality: 5.715851757666088e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9633079493996662), 'phi_r': np.float64(0.08687189668661591), 'phi_45': np.float64(0.0548476837361299)}, 'hwp': {'phi': np.float64(3.1681580687248)}, 'wollaston': {'eta': np.float64(0.9818209628151413)}}
# {'image_rotator': {'phi_h': np.float64(0.7296333339397385), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.1768439732586704)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.5829e-01                                    6.83e+00
#        1              2         1.7335e-02      2.41e-01       2.85e-01       6.69e-01
#        2              3         1.5819e-02      1.52e-03       1.86e-02       9.74e-03
#        3              4         1.5790e-02      2.97e-05       3.68e-03       1.00e-03
#        4              5         1.5790e-02      2.06e-07       3.28e-04       8.26e-05
#        5              6         1.5790e-02      3.43e-10       1.49e-05       6.15e-06
#        6              7         1.5790e-02      1.21e-12       8.79e-07       3.90e-07
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.5829e-01, final cost 1.5790e-02, first-order optimality 3.90e-07.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 1.298e-04 -2.788e-02 ...  8.095e-03 -3.370e-02]
#            x: [ 9.778e-01  9.196e-02  6.616e-02  3.213e+00  9.746e-01]
#         cost: 0.01578952969061613
#          jac: [[ 8.251e-01  7.588e-02 ...  4.229e-01 -5.249e-01]
#                [-1.841e-02 -1.724e-05 ... -4.229e-01 -3.047e-02]
#                ...
#                [-5.715e-01 -6.348e-01 ...  2.063e-01  3.459e-01]
#                [ 2.613e-02 -1.551e-03 ...  5.067e-01  3.808e-02]]
#         grad: [-1.492e-08 -6.294e-08  1.241e-07  9.157e-08  9.982e-10]
#   optimality: 3.8966711580683725e-07
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9778156857959959), 'phi_r': np.float64(0.09195996181053244), 'phi_45': np.float64(0.06616202775280194)}, 'hwp': {'phi': np.float64(3.2133393925693157)}, 'wollaston': {'eta': np.float64(0.9746143470059987)}}
# {'image_rotator': {'phi_h': np.float64(0.7412513078349483), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.225433896298193)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.9440e-01                                    7.50e+00
#        1              2         1.8954e-02      2.75e-01       2.90e-01       7.13e-01
#        2              3         1.7801e-02      1.15e-03       1.73e-02       2.02e-02
#        3              4         1.7786e-02      1.47e-05       3.04e-03       1.50e-03
#        4              5         1.7786e-02      1.06e-07       2.67e-04       1.75e-04
#        5              6         1.7786e-02      5.11e-10       1.73e-05       1.15e-05
#        6              7         1.7786e-02      2.52e-12       1.26e-06       1.24e-06
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.9440e-01, final cost 1.7786e-02, first-order optimality 1.24e-06.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-8.316e-03 -3.011e-02 ...  4.838e-03 -3.387e-02]
#            x: [ 9.972e-01  8.579e-02  6.802e-02  3.253e+00  9.530e-01]
#         cost: 0.017786251511130988
#          jac: [[ 8.253e-01  6.882e-02 ...  4.268e-01 -4.912e-01]
#                [-2.620e-02 -7.647e-05 ... -4.268e-01 -4.848e-02]
#                ...
#                [-5.612e-01 -6.125e-01 ...  1.979e-01  3.473e-01]
#                [ 3.949e-02 -2.184e-03 ...  4.907e-01  5.936e-02]]
#         grad: [-4.770e-08 -1.074e-08  2.430e-08  3.808e-07 -7.574e-10]
#   optimality: 1.2387793811726284e-06
#  active_mask: [0 0 0 0 0]
#         nfev: 7
#         njev: 7
# {'image_rotator': {'phi_h': np.float64(0.9972436811808442), 'phi_r': np.float64(0.0857878376273837), 'phi_45': np.float64(0.0680222918742365)}, 'hwp': {'phi': np.float64(3.2531542420014943)}, 'wollaston': {'eta': np.float64(0.9530180081762101)}}

# %% [markdown]
# # Step 2: Plot $s_{rel}$
# This will allow you to compare how your model performs with other CHARIS pol cals.

# %%
plt.scatter(wavelength_bins, s_rels)

# %% [markdown]
# # Step 3: View Model

# %% [markdown]
# You can visualize your model in a few different ways from your directory of .txt files. One, there is a function that creates a data frame from your directory of .txt files. This will allow for more custom plotting. Two, there are a few different plotting functions in `plotting.py` that plot parameters from your .txt directory. I will show the first.

# %%
from pyPolCal.csv_tools import model_data

jsondir = 'wavelength_fit_results'
df = model_data(jsondir)
df
# Out:
#     wavelength_bin   hwp_phi  image_rotator_phi_45  image_rotator_phi_h  \
# 0        1159.5614  3.035576              0.099326             4.388231
# 1        1199.6971  3.013026              0.110994             4.114816
# 2        1241.2219  3.023356              0.111906             3.908579
# 3        1284.1840  3.049575              0.118123             3.671258
# 4        1328.6331  3.148394              0.116904             3.493774
# 5        1374.6208  2.987005              0.087514             2.683206
# 6        1422.2002  2.953211              0.085745             2.457015
# 7        1471.4264  2.951963              0.076274             2.178729
# 8        1522.3565  2.947950              0.065496             1.935860
# 9        1575.0495  2.952264              0.060341             1.721322
# 10       1629.5663  2.959128              0.056903             1.518196
# 11       1685.9701  2.968260              0.050862             1.354316
# 12       1744.3261  2.982968              0.046620             1.238145
# 13       1804.7021  2.995854              0.045916             1.145335
# 14       1867.1678  3.020882              0.039275             1.063533
# 15       1931.7956  3.044036              0.035476             1.012701
# 16       1998.6603  3.068346              0.038903             0.985856
# 17       2067.8395  3.097594              0.043528             0.964674
# 18       2139.4131  3.133038              0.049832             0.958498
# 19       2213.4641  3.168158              0.054848             0.963308
# 20       2290.0781  3.213339              0.066162             0.977816
# 21       2369.3441  3.253154              0.068022             0.997244
#
#     image_rotator_phi_r  wollaston_eta
# 0          4.685103e-22       1.000000
# 1          8.721196e-28       0.990525
# 2          2.987382e-25       0.995211
# 3          1.136035e-23       0.984636
# 4          2.650599e-29       0.985205
# 5          6.773365e-26       0.989891
# 6          2.880799e-02       0.986202
# 7          5.414960e-02       0.986901
# 8          6.582949e-02       0.986785
# 9          7.978113e-02       0.987338
# 10         8.358190e-02       0.986343
# 11         8.491725e-02       0.986040
# 12         8.890222e-02       0.988291
# 13         9.351764e-02       0.986900
# 14         9.328498e-02       0.987860
# 15         9.010405e-02       0.987356
# 16         9.128208e-02       0.989881
# 17         9.078699e-02       0.986667
# 18         8.976782e-02       0.987520
# 19         8.687190e-02       0.981821
# 20         9.195996e-02       0.974614
# 21         8.578784e-02       0.953018

# %%
imr_phi_r = np.rad2deg(df['image_rotator_phi_h']) # circular retardance from derotator
plt.scatter(wavelength_bins,imr_phi_r)
plt.xlabel('Wavelength (nm)')
plt.ylabel('HWP Retardance (degrees)')
# Out:
# Text(0, 0.5, 'HWP Retardance (degrees)')

# %%
from pyMuellerMat.physical_models.charis_physical_models import HWP_retardance
from pyPolCal.constants import wavelength_bins
plt.plot(wavelength_bins, HWP_retardance(wavelength_bins))
