# %% [markdown]
# # Fitting by Wavelength
# Here you will set offset angles to zero and fit every wavelength-dependent parameter. There are two ways of doing this: the first is following the instructions of this notebook, and the second is modifying the source code one of my wrapper functions in `instruments.py` with your system dictionary. The one I use is `fit_CHARIS_mueller_matrix_by_bin`. You can see examples of that workflow in `CHARIS/minimize`. Before fitting, feel free to plot whatever model you are building off to make sure the fitting function is actually minimizing. Instructions for that are available in `plotting_a_model.ipynb`.

# %% [markdown]
# # Step 1: Fit by Iterating Over All Bins
# The workflow will go like this: per each bin, you 1. read in all data using the `read_csv` function -> 2. initialize your model following instructions in `system_mueller_matrix_tutorial.ipynb` -> 3. set up a `p0_dict` with all parameters that you are fitting for (specifying what components they belong to) -> 4. set bounds for each parameter -> 5. minimize using `scipy.optimize.least_squares()` -> 6. plot the data and fitted model using the procedure laid out in `plotting_a_model.ipynb` -> 7. calculate $s_{rel}$, the relative polarimetric accuracy of your model using the procedure from the Van Holstein 2019 VLT SPHERE polcal -> 8. save the fitted parameters to a .txt file.

# %%
from pyPolCal.csv_tools import read_csv 
from pyPolCal.utils import * 
from pyPolCal.fitting import minimize_system_mueller_matrix, model, process_dataset, process_model, update_p0, update_system_mm
from pyPolCal.plotting import plot_data_and_model
from pyPolCal.constants import wavelength_bins # all CHARIS wavelength bins
from pyMuellerMat.physical_models.charis_physical_models import * # Joost 't Hart 2021 physical models
import numpy as np
import json
from importlib.resources import files

s_rels = []
errors = []
for bin in range(22): # 22 wavelength bins

    ############ PREPARING MODEL #############

    # Define the path to the CSV file for the current bin
    csvpath = f'bin{bin}.csv'
    csvdir = files('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs') / csvpath
     # Read csv
    interleaved_values, interleaved_stds, configuration_list = read_csv(csvdir)
    
    # Load in system dictionary

    system_dict = {
        "components" : {
            "wollaston" : {
            "type" : "wollaston_prism_function",
            "properties" : {"beam": 'o'}, 
            "tag": "internal",
            },
            "nbs": {
                "type" : "rotator_function", # flips Q sign
                "properties" : {"pa": 90},
                "tag": "internal",
            },

            "image_rotator" : {
            "type" : "elliptical_retarder_function",
            "properties" : {"phi_h":0}, # Theta (rotation angle) will be updated by config list
            "tag": "internal",
            },

            "hwp" : {
                "type" : "general_retarder_function",
                "properties" : {"delta_theta": 0}, # Theta (rotation angle) will be updated by config list
                "tag": "internal",
            },


            "lp" :{
                "type" : "diattenuator_retarder_function",
                "properties" : {"epsilon": -1, "theta": 0, "delta_theta":0}, # Perfect calibration polarizer, negative diattenuation to fit CHARIS coordinate system
                "tag": "internal",
            },
    }
    }

    # Converting system dictionary into system Mueller Matrix object
    system_mm = generate_system_mueller_matrix(system_dict)

    ############ FITTING #############

    # Starting guesses for all parameters, I'm taking mine from the Joost't Hart 2021 physical models
    hwp_retardance = HWP_retardance(wavelength_bins)[bin]
    imr_retardance = IMR_retardance(wavelength_bins)[bin]
    wol_eta = 1 # imperfect wollaston fit, using perfect as starting guess

    # p0 dictionary assigning parameters to their components in the system dictionary
    p0 = {
        'hwp': {"phi":hwp_retardance},
        'image_rotator': {'phi_h':imr_retardance, 'phi_r':0, 'phi_45':0},
        'wollaston': {'eta': wol_eta},
    }
    print(p0)

    # Set bounds for each component in order they appear in p0 dictionary
    retardance_bounds = (0,2*np.pi) 
    eta_bounds = (0,1)
    bounds_list = [retardance_bounds,retardance_bounds,retardance_bounds,retardance_bounds,eta_bounds] 

    # Minimize, using process dataset and process model to process everything into double differences
    # Excluding double sums (always do this for CHARIS)
    # Not using aperture errors, works well for our large apertures

    result, new_logl = minimize_system_mueller_matrix(p0, system_mm, interleaved_values, 
    configuration_list, process_dataset=process_dataset,process_model=process_model,include_sums=False, bounds = bounds_list,mode='minimize')
    print(result)

    ########## PLOTTING RESULTS ##########

    # Update p0 and system mueller matrix with fits
    update_p0(p0, result.x)
    print(p0)
    p0_values, p0_keywords = parse_configuration(p0) # parsing updated p0 dictionary
    updated_system_mm = update_system_mm(p0_values, p0_keywords, system_mm)

    # Plot using instructions in plotting_a_model.ipynb
    interleaved_modeled = model(p0_values, p0_keywords, updated_system_mm, configuration_list, 
                                process_model=process_model,s_in=[1,0,0,0])

    # Inputting wavelength to use wavelength as the title
    plot_data_and_model(interleaved_values, interleaved_modeled, configuration_list, 
                                    wavelength=wavelength_bins[bin], include_sums=False)

    ########## CALCULATE S_REL ############

    # Processing single diffs/sums into double diffs/sums
    data_dd = process_dataset(interleaved_values)[::2] # only taking diffs

    # Only taking diffs                                              
    model_dd = interleaved_modeled[::2]

    # Converting resiudals to a percent
    residuals = data_dd*100 - model_dd*100

    # Calculating s_rel
    s_rel = (np.sqrt(np.sum(residuals**2)/(len(data_dd)-len(p0_values)))) / np.sqrt(len(data_dd))
    s_rels.append(s_rel)


    ######### SAVING MODEL ###########

    updated_p0_path = f'wavelength_fit_results/bin{bin}.json'
    with open (updated_p0_path, 'w') as f:
        json.dump(p0, f, indent=4)
# Out:
# {'hwp': {'phi': np.float64(3.001856927823014)}, 'image_rotator': {'phi_h': np.float64(4.530154810514752), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.010913236942217124
#         x: [ 3.017e+00  4.388e+00  0.000e+00  1.091e-01  1.000e+00]
#       nit: 9
#       jac: [-2.024e-07  1.606e-07  1.151e-01  5.985e-08 -1.017e-01]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0171547302562254)}, 'image_rotator': {'phi_h': np.float64(4.387858068001254), 'phi_r': np.float64(0.0), 'phi_45': np.float64(0.10906772089647974)}, 'wollaston': {'eta': np.float64(1.0)}}
# {'hwp': {'phi': np.float64(2.9908432015864457)}, 'image_rotator': {'phi_h': np.float64(4.298515181117285), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.006218572576633901
#         x: [ 3.009e+00  4.115e+00  0.000e+00  1.151e-01  9.909e-01]
#       nit: 10
#       jac: [-3.381e-07 -1.988e-06  8.514e-02 -2.297e-07  1.252e-06]
#      nfev: 72
#      njev: 12
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.008543864938944)}, 'image_rotator': {'phi_h': np.float64(4.114771583104327), 'phi_r': np.float64(0.0), 'phi_45': np.float64(0.1151032167202871)}, 'wollaston': {'eta': np.float64(0.9908755727957992)}}
# {'hwp': {'phi': np.float64(2.9802180654142774)}, 'image_rotator': {'phi_h': np.float64(4.016290856949604), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 0.0026790410296735232
#         x: [ 3.026e+00  3.909e+00  0.000e+00  1.124e-01  9.953e-01]
#       nit: 11
#       jac: [-4.728e-06  6.878e-06  4.776e-02  2.637e-06 -1.121e-05]
#      nfev: 78
#      njev: 13
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.025500247731419)}, 'image_rotator': {'phi_h': np.float64(3.908938890702499), 'phi_r': np.float64(0.0), 'phi_45': np.float64(0.11241025001811981)}, 'wollaston': {'eta': np.float64(0.995270890867433)}}
# {'hwp': {'phi': np.float64(2.97033706726214)}, 'image_rotator': {'phi_h': np.float64(3.6959844091398195), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.0007009399524405145
#         x: [ 3.050e+00  3.672e+00  0.000e+00  1.187e-01  9.849e-01]
#       nit: 8
#       jac: [ 1.155e-06 -5.651e-06  1.869e-02 -5.983e-07  7.053e-06]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0500484649270527)}, 'image_rotator': {'phi_h': np.float64(3.6721996935881536), 'phi_r': np.float64(0.0), 'phi_45': np.float64(0.11866774075294462)}, 'wollaston': {'eta': np.float64(0.9849043008655023)}}
# {'hwp': {'phi': np.float64(2.9615265218152054)}, 'image_rotator': {'phi_h': np.float64(3.361467081420097), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00011780342304662925
#         x: [ 3.138e+00  3.494e+00  0.000e+00  1.179e-01  9.852e-01]
#       nit: 14
#       jac: [-1.293e-06 -5.235e-08  4.184e-03  1.822e-06 -3.722e-06]
#      nfev: 120
#      njev: 20
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.1380180677391727)}, 'image_rotator': {'phi_h': np.float64(3.493813656151462), 'phi_r': np.float64(0.0), 'phi_45': np.float64(0.11794352029439324)}, 'wollaston': {'eta': np.float64(0.9852018717232318)}}
# {'hwp': {'phi': np.float64(2.9540877809862343)}, 'image_rotator': {'phi_h': np.float64(3.007361431522309), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 2.6037021609432554e-05
#         x: [ 3.008e+00  2.683e+00  2.724e-02  8.967e-02  9.882e-01]
#       nit: 19
#       jac: [-1.540e-06 -8.778e-06  3.983e-06  2.113e-06 -8.769e-06]
#      nfev: 144
#      njev: 24
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0079397817579565)}, 'image_rotator': {'phi_h': np.float64(2.6832217152064586), 'phi_r': np.float64(0.02724369091344896), 'phi_45': np.float64(0.08967436687503257)}, 'wollaston': {'eta': np.float64(0.9881764876119886)}}
# {'hwp': {'phi': np.float64(2.9483013148482353)}, 'image_rotator': {'phi_h': np.float64(2.658791656657683), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 8.443837803477931e-05
#         x: [ 2.970e+00  2.458e+00  4.688e-02  8.815e-02  9.844e-01]
#       nit: 12
#       jac: [ 7.927e-07  1.893e-06 -1.048e-06 -3.098e-06  1.200e-05]
#      nfev: 84
#      njev: 14
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.9702222396455156)}, 'image_rotator': {'phi_h': np.float64(2.4575121407798832), 'phi_r': np.float64(0.046878610694668234), 'phi_45': np.float64(0.08815271994560721)}, 'wollaston': {'eta': np.float64(0.9843768752590402)}}
# {'hwp': {'phi': np.float64(2.9444303373174208)}, 'image_rotator': {'phi_h': np.float64(2.329506952088865), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00019473036118664824
#         x: [ 2.968e+00  2.179e+00  6.241e-02  7.859e-02  9.855e-01]
#       nit: 10
#       jac: [ 7.806e-07 -8.658e-07  3.179e-06 -3.521e-06 -2.097e-06]
#      nfev: 72
#      njev: 12
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.967670385154375)}, 'image_rotator': {'phi_h': np.float64(2.178625103251582), 'phi_r': np.float64(0.0624062946438658), 'phi_45': np.float64(0.07859045519677528)}, 'wollaston': {'eta': np.float64(0.9855464554794434)}}
# {'hwp': {'phi': np.float64(2.9427243097474256)}, 'image_rotator': {'phi_h': np.float64(2.0376892427031716), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00021281348547664539
#         x: [ 2.966e+00  1.936e+00  7.036e-02  6.842e-02  9.855e-01]
#       nit: 9
#       jac: [-3.837e-07 -3.121e-06 -1.786e-06 -9.955e-08  1.076e-06]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.9658173200142337)}, 'image_rotator': {'phi_h': np.float64(1.9355081475240978), 'phi_r': np.float64(0.07036438778027759), 'phi_45': np.float64(0.06842197474005571)}, 'wollaston': {'eta': np.float64(0.985492278897979)}}
# {'hwp': {'phi': np.float64(2.943422236996289)}, 'image_rotator': {'phi_h': np.float64(1.7689132118012587), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00019894446443434553
#         x: [ 2.972e+00  1.721e+00  8.069e-02  6.493e-02  9.862e-01]
#       nit: 10
#       jac: [-6.243e-08  1.362e-07  3.521e-09 -5.385e-08  1.242e-08]
#      nfev: 78
#      njev: 13
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.971843805006712)}, 'image_rotator': {'phi_h': np.float64(1.7207164547146752), 'phi_r': np.float64(0.08069341310196843), 'phi_45': np.float64(0.0649251771648188)}, 'wollaston': {'eta': np.float64(0.9862090709927024)}}
# {'hwp': {'phi': np.float64(2.94675578039066)}, 'image_rotator': {'phi_h': np.float64(1.5364262782470774), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.0003016949468142505
#         x: [ 2.977e+00  1.518e+00  8.599e-02  5.931e-02  9.854e-01]
#       nit: 7
#       jac: [-7.759e-07  3.633e-06  2.623e-06  4.515e-06  3.174e-06]
#      nfev: 54
#      njev: 9
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.9769336236830535)}, 'image_rotator': {'phi_h': np.float64(1.5181196888544126), 'phi_r': np.float64(0.08598925999124336), 'phi_45': np.float64(0.05930716247406122)}, 'wollaston': {'eta': np.float64(0.9853879714418219)}}
# {'hwp': {'phi': np.float64(2.9529523030518745)}, 'image_rotator': {'phi_h': np.float64(1.337879684752699), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.0002781973498420133
#         x: [ 2.987e+00  1.354e+00  8.688e-02  5.295e-02  9.852e-01]
#       nit: 9
#       jac: [-9.579e-08 -4.655e-08 -1.905e-07  1.539e-07 -2.339e-07]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(2.987398467864833)}, 'image_rotator': {'phi_h': np.float64(1.3544488207620133), 'phi_r': np.float64(0.08687623694473173), 'phi_45': np.float64(0.05295369130509277)}, 'wollaston': {'eta': np.float64(0.9851740481644303)}}
# {'hwp': {'phi': np.float64(2.962237827816352)}, 'image_rotator': {'phi_h': np.float64(1.1782478110981653), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00014102171415875868
#         x: [ 3.001e+00  1.238e+00  8.953e-02  5.087e-02  9.875e-01]
#       nit: 9
#       jac: [-7.420e-08 -2.541e-07  1.600e-06  8.889e-08 -4.870e-06]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.000969223268701)}, 'image_rotator': {'phi_h': np.float64(1.2379838763985107), 'phi_r': np.float64(0.08952575533440493), 'phi_45': np.float64(0.05087007658553754)}, 'wollaston': {'eta': np.float64(0.9875439737046995)}}
# {'hwp': {'phi': np.float64(2.9748400845824543)}, 'image_rotator': {'phi_h': np.float64(1.0458778179531958), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 0.00015037047210759928
#         x: [ 3.008e+00  1.145e+00  9.351e-02  5.032e-02  9.864e-01]
#       nit: 9
#       jac: [ 1.641e-05  2.218e-05 -1.037e-05 -4.744e-05  1.694e-05]
#      nfev: 66
#      njev: 11
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0076717974569687)}, 'image_rotator': {'phi_h': np.float64(1.1450180149955096), 'phi_r': np.float64(0.09350835996049799), 'phi_45': np.float64(0.05031655839678546)}, 'wollaston': {'eta': np.float64(0.9864197626169874)}}
# {'hwp': {'phi': np.float64(2.9909913816183407)}, 'image_rotator': {'phi_h': np.float64(0.9411728208731114), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00011446630301875643
#         x: [ 3.030e+00  1.063e+00  9.253e-02  4.787e-02  9.874e-01]
#       nit: 11
#       jac: [ 2.931e-07 -1.038e-07 -3.216e-07 -8.770e-07  3.908e-07]
#      nfev: 84
#      njev: 14
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0300784503126743)}, 'image_rotator': {'phi_h': np.float64(1.062553287142509), 'phi_r': np.float64(0.09253051579885642), 'phi_45': np.float64(0.047866584618354045)}, 'wollaston': {'eta': np.float64(0.9874392677425808)}}
# {'hwp': {'phi': np.float64(3.0109318293578498)}, 'image_rotator': {'phi_h': np.float64(0.8612584400689047), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 7.118071494987694e-05
#         x: [ 3.057e+00  1.012e+00  8.945e-02  4.658e-02  9.869e-01]
#       nit: 10
#       jac: [ 4.788e-06  8.388e-06 -4.258e-06 -1.209e-05 -1.624e-05]
#      nfev: 72
#      njev: 12
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0574390922261157)}, 'image_rotator': {'phi_h': np.float64(1.0116443384146314), 'phi_r': np.float64(0.08944972739182235), 'phi_45': np.float64(0.04658085822476298)}, 'wollaston': {'eta': np.float64(0.9869468309894468)}}
# {'hwp': {'phi': np.float64(3.0349124963396106)}, 'image_rotator': {'phi_h': np.float64(0.8030305075769144), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 3.554647996753219e-05
#         x: [ 3.080e+00  9.850e-01  9.078e-02  4.865e-02  9.897e-01]
#       nit: 11
#       jac: [-7.123e-07  2.200e-06 -6.383e-06 -8.124e-08 -4.135e-06]
#      nfev: 78
#      njev: 13
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.0797171514667654)}, 'image_rotator': {'phi_h': np.float64(0.9850397384171055), 'phi_r': np.float64(0.09078203556189883), 'phi_45': np.float64(0.04864673748964083)}, 'wollaston': {'eta': np.float64(0.9896726385558425)}}
# {'hwp': {'phi': np.float64(3.0631989509178603)}, 'image_rotator': {'phi_h': np.float64(0.7635782257098833), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 4.183881934088708e-05
#         x: [ 3.108e+00  9.642e-01  9.057e-02  5.072e-02  9.866e-01]
#       nit: 11
#       jac: [ 1.213e-05  2.805e-06 -1.083e-05 -3.081e-05  1.183e-05]
#      nfev: 78
#      njev: 13
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.10839514851435)}, 'image_rotator': {'phi_h': np.float64(0.9642285339204772), 'phi_r': np.float64(0.09057371923899286), 'phi_45': np.float64(0.05072290721943725)}, 'wollaston': {'eta': np.float64(0.9866497659469133)}}
# {'hwp': {'phi': np.float64(3.0960747250300913)}, 'image_rotator': {'phi_h': np.float64(0.740037727221333), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 2.311615823709683e-05
#         x: [ 3.140e+00  9.584e-01  8.980e-02  5.285e-02  9.876e-01]
#       nit: 12
#       jac: [-5.728e-07  1.440e-06 -8.567e-07 -1.132e-07 -2.166e-06]
#      nfev: 84
#      njev: 14
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.1401278070218637)}, 'image_rotator': {'phi_h': np.float64(0.9583820005918194), 'phi_r': np.float64(0.08979639196389495), 'phi_45': np.float64(0.05285488039123115)}, 'wollaston': {'eta': np.float64(0.9876188141630413)}}
# {'hwp': {'phi': np.float64(3.133845633636237)}, 'image_rotator': {'phi_h': np.float64(0.7275457894546419), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 5.0221441470718e-05
#         x: [ 3.178e+00  9.633e-01  8.727e-02  5.503e-02  9.821e-01]
#       nit: 12
#       jac: [-8.691e-06  1.831e-05 -1.886e-05  1.791e-05 -1.996e-05]
#      nfev: 84
#      njev: 14
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.177599780895988)}, 'image_rotator': {'phi_h': np.float64(0.963304034194985), 'phi_r': np.float64(0.08726733067214301), 'phi_45': np.float64(0.055031784069949984)}, 'wollaston': {'eta': np.float64(0.9820515119817766)}}
# {'hwp': {'phi': np.float64(3.1768439732586704)}, 'image_rotator': {'phi_h': np.float64(0.7296333339397385), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 0.00011711509942940215
#         x: [ 3.214e+00  9.778e-01  9.264e-02  5.930e-02  9.745e-01]
#       nit: 13
#       jac: [-4.204e-07  3.499e-07 -7.478e-07 -3.710e-08 -5.857e-07]
#      nfev: 90
#      njev: 15
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.2136300018952197)}, 'image_rotator': {'phi_h': np.float64(0.9778052493037127), 'phi_r': np.float64(0.0926436623368793), 'phi_45': np.float64(0.059298620491262666)}, 'wollaston': {'eta': np.float64(0.974478137709156)}}
# {'hwp': {'phi': np.float64(3.225433896298193)}, 'image_rotator': {'phi_h': np.float64(0.7412513078349483), 'phi_r': 0, 'phi_45': 0}, 'wollaston': {'eta': 1}}
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 0.0001744509640856
#         x: [ 3.272e+00  9.966e-01  8.730e-02  6.256e-02  9.539e-01]
#       nit: 12
#       jac: [ 9.905e-06  1.253e-05 -2.741e-05 -3.501e-05  2.554e-06]
#      nfev: 90
#      njev: 15
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
# {'hwp': {'phi': np.float64(3.272263088834713)}, 'image_rotator': {'phi_h': np.float64(0.9966399941674785), 'phi_r': np.float64(0.08730248976702638), 'phi_45': np.float64(0.06256428335850296)}, 'wollaston': {'eta': np.float64(0.9538717193568642)}}

# %% [markdown]
# # Step 2: Calculate and Plot $s_{rel}$
# This is the relative polarimetric accuracy of the model.

# %%
plt.scatter(wavelength_bins, s_rels)

# %% [markdown]
# # Step 3: View Model

# %% [markdown]
# You can visualize your model in a few different ways from your directory of .txt files. One, there is a function that creates a data frame from your directory of .txt files. This will allow for more custom plotting. Two, there are a few different plotting functions in `plotting.py` that plot parameters from your .txt directory. I will show the first.

# %%
from pyPolCal.csv_tools import model_data

jsondir = 'wavelength_fit_results'
df = model_data(jsondir)
df
# Out:
#     wavelength_bin   hwp_phi  image_rotator_phi_45  image_rotator_phi_h  \
# 0        1159.5614  3.017155              0.109068             4.387858
# 1        1199.6971  3.008544              0.115103             4.114772
# 2        1241.2219  3.025500              0.112410             3.908939
# 3        1284.1840  3.050048              0.118668             3.672200
# 4        1328.6331  3.138018              0.117944             3.493814
# 5        1374.6208  3.007940              0.089674             2.683222
# 6        1422.2002  2.970222              0.088153             2.457512
# 7        1471.4264  2.967670              0.078590             2.178625
# 8        1522.3565  2.965817              0.068422             1.935508
# 9        1575.0495  2.971844              0.064925             1.720716
# 10       1629.5663  2.976934              0.059307             1.518120
# 11       1685.9701  2.987398              0.052954             1.354449
# 12       1744.3261  3.000969              0.050870             1.237984
# 13       1804.7021  3.007672              0.050317             1.145018
# 14       1867.1678  3.030078              0.047867             1.062553
# 15       1931.7956  3.057439              0.046581             1.011644
# 16       1998.6603  3.079717              0.048647             0.985040
# 17       2067.8395  3.108395              0.050723             0.964229
# 18       2139.4131  3.140128              0.052855             0.958382
# 19       2213.4641  3.177600              0.055032             0.963304
# 20       2290.0781  3.213630              0.059299             0.977805
# 21       2369.3441  3.272263              0.062564             0.996640
#
#     image_rotator_phi_r  wollaston_eta
# 0              0.000000       1.000000
# 1              0.000000       0.990876
# 2              0.000000       0.995271
# 3              0.000000       0.984904
# 4              0.000000       0.985202
# 5              0.027244       0.988176
# 6              0.046879       0.984377
# 7              0.062406       0.985546
# 8              0.070364       0.985492
# 9              0.080693       0.986209
# 10             0.085989       0.985388
# 11             0.086876       0.985174
# 12             0.089526       0.987544
# 13             0.093508       0.986420
# 14             0.092531       0.987439
# 15             0.089450       0.986947
# 16             0.090782       0.989673
# 17             0.090574       0.986650
# 18             0.089796       0.987619
# 19             0.087267       0.982052
# 20             0.092644       0.974478
# 21             0.087302       0.953872

# %%
imr_phi_r = np.rad2deg(df['image_rotator_phi_r']) # circular retardance from derotator
plt.scatter(wavelength_bins,imr_phi_r)
plt.xlabel('Wavelength (nm)')
plt.ylabel('IMR Circular Retardance (degrees)')
# Out:
# Text(0, 0.5, 'IMR Circular Retardance (degrees)')
