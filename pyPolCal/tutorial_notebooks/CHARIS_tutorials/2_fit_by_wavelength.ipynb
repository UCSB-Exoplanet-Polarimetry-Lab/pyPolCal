# %% [markdown]
# # Fitting by Wavelength
# Here you will set offset angles to zero and fit every wavelength-dependent parameter. There are two ways of doing this: the first is following the instructions of this notebook, and the second is modifying the source code one of my wrapper functions in `instruments.py` with your system dictionary. The one I use is `fit_CHARIS_mueller_matrix_by_bin`. You can see examples of that workflow in `CHARIS/minimize`. Before fitting, feel free to plot whatever model you are building off to make sure the fitting function is actually minimizing. Instructions for that are available in `plotting_a_model.ipynb`.

# %% [markdown]
# # Fit by Iterating Over All Bins
# The workflow will go like this: per each bin, you 1. read in all data using the `read_csv` function -> 2. initialize your model following instructions in `system_mueller_matrix_tutorial.ipynb` -> 3. set up a `p0_dict` with all parameters that you are fitting for (specifying what components they belong to) -> 4. set bounds for each parameter -> 5. minimize using `scipy.optimize.least_squares()` -> 6. plot the data and fitted model using the procedure laid out in `plotting_a_model.ipynb` -> 7. calculate $s_{rel}$, the relative polarimetric accuracy of your model using the procedure from the Van Holstein 2019 VLT SPHERE polcal -> 8. save the fitted parameters to a .txt file.

# %%
from pyPolCal.csv_tools import read_csv 
from pyPolCal.utils import * 
from pyPolCal.fitting import minimize_system_mueller_matrix, model, process_dataset, process_model, update_p0, update_system_mm
from pyPolCal.plotting import plot_data_and_model
from pyPolCal.constants import wavelength_bins # all CHARIS wavelength bins
from pyMuellerMat.physical_models.charis_physical_models import * # Joost 't Hart 2021 physical models
import numpy as np
import json
from importlib import resources

s_rels = []
errors = []
for bin in range(22): # 22 wavelength bins

    ############ PREPARING MODEL #############

    # Define the path to the CSV file for the current bin
    csvpath = f'bin{bin}.csv'
    with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
        # Read csv
        interleaved_values, interleaved_stds, configuration_list = read_csv(csvdir)

    # Load in system dictionary

    system_dict = {
        "components" : {
            "wollaston" : {
            "type" : "wollaston_prism_function",
            "properties" : {"beam": 'o'}, 
            "tag": "internal",
            },

            "nbs_rot": {
                "type": "rotator_function",
                "properties": {"pa": 90},
                "tag": "internal",
            },
            "image_rotator" : {
            "type" : "elliptical_retarder_function",
            "properties" : {"delta_theta":0}, # Theta (rotation angle) will be updated by config list
            "tag": "internal",
            },
            
            "hwp" : {
                "type" : "diattenuator_retarder_function",
                "properties" : {"delta_theta": 0}, # Theta (rotation angle) will be updated by config list
                "tag": "internal",
            },


            "lp" :{
                "type" : "diattenuator_retarder_function",
                "properties" : {"epsilon": 1, "delta_theta":0}, # Perfect calibration polarizer
                "tag": "internal",
            },
    }
    }

    # Converting system dictionary into system Mueller Matrix object
    system_mm = generate_system_mueller_matrix(system_dict)

    ############ FITTING #############

    # Starting guesses for all parameters, I'm taking mine from the Joost't Hart 2021 physical models
    hwp_retardance = HWP_retardance(wavelength_bins)[bin]
    imr_retardance = IMR_retardance(wavelength_bins)[bin]
    wol_eta = 1 # imperfect wollaston fit, using perfect as starting guess

    # p0 dictionary assigning parameters to their components in the system dictionary
    p0 = {
        "image_rotator": {"phi_h":imr_retardance, "phi_r":0, "phi_45":0}, # linear retarder for starting guess
        'hwp': {"phi":hwp_retardance},
        'wollaston': {'eta': wol_eta}
    }
    print(p0)

    # Set bounds for each component in order they appear in p0 dictionary
    retardance_bounds = (0,2*np.pi) 
    eta_bounds = (0,1)
    bounds_list = [retardance_bounds, retardance_bounds, retardance_bounds, retardance_bounds, eta_bounds]

    # Minimize, using process dataset and process model to process everything into double differences
    # Excluding double sums (always do this for CHARIS)
    # Not using aperture errors, works well for our large apertures

    result, new_logl, error = minimize_system_mueller_matrix(p0, system_mm, interleaved_values, 
    configuration_list, process_dataset=process_dataset,process_model=process_model,include_sums=False, bounds = bounds_list,mode='least_squares')
    print(result)
    errors.append(error)

    ########## PLOTTING RESULTS ##########

    # Update p0 and system mueller matrix with fits
    update_p0(p0, result.x)
    print(p0)
    p0_values, p0_keywords = parse_configuration(p0) # parsing updated p0 dictionary
    updated_system_mm = update_system_mm(p0_values, p0_keywords, system_mm)

    # Plot using instructions in plotting_a_model.ipynb
    interleaved_modeled = model(p0_values, p0_keywords, updated_system_mm, configuration_list, 
                                process_model=process_model,s_in=[1,0,0,0])

    # Inputting wavelength to use wavelength as the title
    plot_data_and_model(interleaved_values, interleaved_modeled, configuration_list, 
                                    wavelength=wavelength_bins[bin], include_sums=False)

    ########## CALCULATE S_REL ############

    # Processing single diffs/sums into double diffs/sums
    data_dd = process_dataset(interleaved_values)[::2] # only taking diffs

    # Only taking diffs                                              
    model_dd = interleaved_modeled[::2]

    # Converting resiudals to a percent
    residuals = data_dd*100 - model_dd*100

    # Calculating s_rel
    s_rel = np.sqrt(np.sum(residuals**2)/(len(data_dd)-len(p0_values)))
    s_rels.append(s_rel)


    ######### SAVING MODEL ###########

    updated_p0_path = f'wavelength_fit_results/bin{bin}.json'
    with open (updated_p0_path, 'w') as f:
        json.dump(p0, f, indent=4)
# Out:
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(4.530154810514752), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.001856927823014)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.5368e+00                                    8.98e+00
#        1              2         3.4609e+00      2.08e+00       6.43e-01       3.05e+00
#        2              3         3.1160e+00      3.45e-01       2.32e+00       2.25e+00
#        3              4         3.0846e+00      3.14e-02       1.27e-01       5.63e-01
#        4              5         3.0699e+00      1.47e-02       2.66e-01       9.14e-01
#        5              6         3.0643e+00      5.60e-03       5.19e-02       1.35e-01
#        6              7         3.0624e+00      1.95e-03       6.17e-02       2.49e-01
#        7              8         3.0620e+00      3.79e-04       1.34e-02       6.57e-02
#        8              9         3.0618e+00      1.71e-04       2.34e-02       1.02e-01
#        9             10         3.0618e+00      6.55e-05       5.51e-03       2.52e-02
#       10             11         3.0617e+00      3.39e-05       1.04e-02       4.48e-02
#       11             12         3.0617e+00      1.22e-05       2.37e-03       9.39e-03
#       12             13         3.0617e+00      4.61e-06       3.98e-03       1.64e-02
#       13             14         3.0617e+00      1.64e-06       8.63e-04       3.29e-03
#       14             15         3.0617e+00      5.79e-07       1.40e-03       5.77e-03
#       15             16         3.0617e+00      2.03e-07       3.04e-04       1.16e-03
#       16             17         3.0617e+00      7.06e-08       4.92e-04       2.02e-03
#       17             18         3.0617e+00      2.48e-08       1.06e-04       4.06e-04
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 5.5368e+00, final cost 3.0617e+00, first-order optimality 4.06e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 4.695e-01 -8.902e-02 ... -4.110e-01 -7.773e-02]
#            x: [ 4.387e+00  1.848e+00  9.893e-15  5.107e+00  5.821e-01]
#         cost: 3.061718294135877
#          jac: [[ 3.393e-01  1.837e-01 ...  0.000e+00  1.614e-01]
#                [ 3.751e-01  1.174e-01 ...  0.000e+00 -9.716e-02]
#                ...
#                [ 2.334e-01 -1.315e-02 ...  0.000e+00 -2.495e-01]
#                [ 1.828e-01 -3.962e-02 ...  0.000e+00 -2.674e-01]]
#         grad: [-2.699e-06 -9.149e-05  6.446e-01  0.000e+00 -9.888e-05]
#   optimality: 0.0004057199840032075
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 18
#         njev: 18
# {'image_rotator': {'phi_h': np.float64(4.387060136203921), 'phi_r': np.float64(1.8484929650123518), 'phi_45': np.float64(9.893231775099974e-15)}, 'hwp': {'phi': np.float64(5.1067548900880535)}, 'wollaston': {'eta': np.float64(0.5821304098288812)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(4.298515181117285), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9908432015864457)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.3144e+00                                    7.51e+00
#        1              2         4.2007e+00      2.11e+00       2.36e+00       1.72e+00
#        2              3         3.9592e+00      2.41e-01       2.60e-01       1.00e+00
#        3              4         3.9412e+00      1.80e-02       1.10e-01       2.14e-01
#        4              5         3.9352e+00      6.03e-03       4.54e-02       1.91e-01
#        5              6         3.9346e+00      5.53e-04       2.25e-02       2.75e-02
#        6              7         3.9345e+00      1.68e-04       7.34e-03       3.73e-02
#        7              8         3.9344e+00      1.83e-05       4.09e-03       4.64e-03
#        8              9         3.9344e+00      5.08e-06       1.03e-03       7.46e-03
#        9             10         3.9344e+00      7.50e-07       8.12e-04       8.18e-04
#       10             11         3.9344e+00      3.72e-07       4.15e-04       2.32e-03
#       11             12         3.9344e+00      1.66e-07       3.31e-04       8.42e-04
#       12             13         3.9344e+00      3.89e-07       8.53e-04       4.01e-03
#       13             14         3.9344e+00      1.42e-06       4.39e+00       1.68e-05
#       14             15         3.9344e+00      4.35e-12       1.72e-06       2.98e-06
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 6.3144e+00, final cost 3.9344e+00, first-order optimality 2.98e-06.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 5.572e-01 -1.679e-01 ... -5.335e-01 -1.813e-02]
#            x: [ 4.338e+00  9.814e-01  1.440e-18  8.220e-01  4.610e-01]
#         cost: 3.9344398272862566
#          jac: [[ 2.908e-01  9.913e-02 ...  0.000e+00 -1.031e-01]
#                [ 2.879e-01  3.178e-02 ...  0.000e+00 -2.451e-01]
#                ...
#                [ 1.436e-01 -5.759e-02 ...  0.000e+00 -1.967e-01]
#                [ 1.005e-01 -7.149e-02 ...  0.000e+00 -1.767e-01]]
#         grad: [-4.974e-07  3.041e-06  8.876e-01  0.000e+00  1.044e-06]
#   optimality: 2.9841477184074343e-06
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 15
#         njev: 15
# {'image_rotator': {'phi_h': np.float64(4.338484861515031), 'phi_r': np.float64(0.9814378963840646), 'phi_45': np.float64(1.4397943203987127e-18)}, 'hwp': {'phi': np.float64(0.8220153600669118)}, 'wollaston': {'eta': np.float64(0.4609965759992652)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(4.016290856949604), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9802180654142774)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.5784e+00                                    9.39e+00
#        1              2         5.1990e+00      2.38e+00       4.06e-01       2.38e+00
#        2              3         4.7656e+00      4.33e-01       2.48e-01       1.33e+00
#        3              4         4.6852e+00      8.04e-02       2.48e-01       2.30e-01
#        4              5         4.6770e+00      8.22e-03       1.85e+00       2.62e-02
#        5              6         4.6769e+00      6.01e-05       1.09e-02       9.62e-04
#        6              7         4.6769e+00      2.17e-07       1.91e-04       1.19e-03
#        7              8         4.6769e+00      7.80e-08       3.34e-04       3.73e-04
#        8              9         4.6769e+00      7.37e-08       1.44e-04       7.07e-04
#        9             10         4.6769e+00      4.43e-08       1.49e-04       3.15e-04
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 7.5784e+00, final cost 4.6769e+00, first-order optimality 3.15e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 6.076e-01 -2.004e-01 ... -6.408e-01  2.317e-03]
#            x: [ 4.092e+00  4.456e-01  1.459e-14  1.133e+00  4.096e-01]
#         cost: 4.676890002873793
#          jac: [[ 2.299e-01  5.248e-02 ...  0.000e+00 -3.446e-01]
#                [ 2.193e-01 -3.561e-03 ...  0.000e+00 -4.044e-01]
#                ...
#                [ 9.933e-02 -6.224e-02 ...  0.000e+00 -1.880e-01]
#                [ 6.531e-02 -6.933e-02 ...  0.000e+00 -1.332e-01]]
#         grad: [-1.180e-04  7.060e-04  1.200e+00  0.000e+00  5.536e-04]
#   optimality: 0.0003146363047958874
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 10
#         njev: 10
# {'image_rotator': {'phi_h': np.float64(4.0917017547836485), 'phi_r': np.float64(0.44564611770991486), 'phi_45': np.float64(1.4590898433390387e-14)}, 'hwp': {'phi': np.float64(1.1326747015565577)}, 'wollaston': {'eta': np.float64(0.40961171307426)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(3.6959844091398195), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.97033706726214)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.9072e+00                                    1.18e+01
#        1              2         5.7246e+00      3.18e+00       4.32e-01       2.52e+00
#        2              3         5.3031e+00      4.22e-01       2.07e+00       4.95e-01
#        3              4         5.2716e+00      3.15e-02       5.67e-02       5.28e-01
#        4              5         5.2600e+00      1.16e-02       1.49e-01       9.92e-02
#        5              6         5.2568e+00      3.12e-03       7.67e-02       7.86e-02
#        6              7         5.2558e+00      9.95e-04       1.05e-02       5.89e-02
#        7              8         5.2545e+00      1.32e-03       3.60e+00       6.37e-03
#        8             10         5.2545e+00      4.73e-06       2.18e-04       6.27e-03
#        9             11         5.2545e+00      2.00e-06       6.54e-04       1.42e-03
#       10             12         5.2545e+00      2.35e-07       9.09e-04       1.53e-04
#       11             13         5.2545e+00      5.88e-09       3.41e-05       3.01e-04
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 8.9072e+00, final cost 5.2545e+00, first-order optimality 3.01e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 6.544e-01 -2.277e-01 ... -7.352e-01 -1.032e-02]
#            x: [ 3.785e+00  3.816e-06  3.624e-17  4.506e+00  3.923e-01]
#         cost: 5.254514980199261
#          jac: [[ 1.568e-01  2.072e-02 ...  0.000e+00 -5.335e-01]
#                [ 1.568e-01 -2.072e-02 ...  0.000e+00 -5.335e-01]
#                ...
#                [ 7.845e-02 -5.318e-02 ...  0.000e+00 -1.895e-01]
#                [ 5.513e-02 -5.567e-02 ...  0.000e+00 -1.074e-01]]
#         grad: [ 7.946e-05  2.296e-02  1.571e+00  0.000e+00 -6.929e-05]
#   optimality: 0.0003007124419132401
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 13
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(3.7846357774550636), 'phi_r': np.float64(3.816118864923186e-06), 'phi_45': np.float64(3.624271932572985e-17)}, 'hwp': {'phi': np.float64(4.506445193843204)}, 'wollaston': {'eta': np.float64(0.39228498976461074)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(3.361467081420097), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9615265218152054)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.7760e+00                                    1.35e+01
#        1              2         6.1831e+00      3.59e+00       4.00e-01       3.02e+00
#        2              3         5.6547e+00      5.28e-01       2.98e+00       4.62e-01
#        3              4         5.6307e+00      2.39e-02       4.80e-02       2.67e-01
#        4              5         5.6241e+00      6.61e-03       1.42e-01       7.18e-02
#        5              6         5.6239e+00      1.67e-04       7.24e-03       2.89e-02
#        6              7         5.6238e+00      1.10e-04       1.59e-02       2.19e-02
#        7              8         5.6238e+00      1.23e-05       2.47e-03       1.02e-02
#        8              9         5.6238e+00      1.28e-05       5.12e-03       1.28e-02
#        9             10         5.6238e+00      5.32e-06       1.30e-03       5.56e-03
#       10             11         5.6238e+00      6.03e-06       3.63e+00       1.87e-04
#       11             12         5.6238e+00      1.03e-09       3.58e-05       7.37e-05
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 9.7760e+00, final cost 5.6238e+00, first-order optimality 7.37e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 6.836e-01 -2.363e-01 ... -8.115e-01 -5.335e-02]
#            x: [ 3.670e+00  2.292e-13  4.334e-19  2.288e+00  4.105e-01]
#         cost: 5.623795017434444
#          jac: [[ 1.380e-01  1.880e-02 ...  0.000e+00 -5.756e-01]
#                [ 1.380e-01 -1.880e-02 ...  0.000e+00 -5.756e-01]
#                ...
#                [ 6.905e-02 -4.827e-02 ...  0.000e+00 -2.106e-01]
#                [ 4.852e-02 -5.052e-02 ...  0.000e+00 -1.222e-01]]
#         grad: [ 2.008e-05  4.894e-02  1.863e+00  0.000e+00  1.337e-04]
#   optimality: 7.369878581324135e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 12
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(3.670297812123112), 'phi_r': np.float64(2.291855490643269e-13), 'phi_45': np.float64(4.3336285054282495e-19)}, 'hwp': {'phi': np.float64(2.2875356550164345)}, 'wollaston': {'eta': np.float64(0.4104529805875822)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(3.007361431522309), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9540877809862343)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.4133e+00                                    1.36e+01
#        1              2         5.8257e+00      3.59e+00       3.88e-01       3.13e+00
#        2              3         5.2832e+00      5.43e-01       1.80e-01       5.83e-01
#        3              4         5.2428e+00      4.04e-02       6.88e-02       2.34e-01
#        4              5         5.2391e+00      3.68e-03       9.69e-02       1.72e-01
#        5              7         5.2318e+00      7.32e-03       1.09e-01       1.41e-01
#        6              8         5.2247e+00      7.04e-03       2.40e-01       4.25e-02
#        7              9         5.2241e+00      6.94e-04       2.30e-01       5.17e-03
#        8             13         5.2240e+00      3.77e-06       4.95e-03       4.22e-05
#        9             14         5.2240e+00      1.73e-10       4.78e-06       3.50e-05
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 9.4133e+00, final cost 5.2240e+00, first-order optimality 3.50e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 5.847e-01 -2.082e-01 ... -7.702e-01 -6.549e-02]
#            x: [ 2.574e+00  5.221e-01  1.204e-18  2.740e+00  4.345e-01]
#         cost: 5.224047389165977
#          jac: [[-1.100e-01 -4.948e-02 ...  0.000e+00 -6.128e-01]
#                [-1.697e-01 -7.255e-03 ...  0.000e+00 -5.475e-01]
#                ...
#                [-1.454e-01  3.073e-02 ...  0.000e+00 -1.348e-01]
#                [-1.281e-01  3.715e-02 ...  0.000e+00 -4.202e-02]]
#         grad: [ 1.360e-05 -1.134e-06  2.672e+00  0.000e+00  4.527e-06]
#   optimality: 3.5013367290311777e-05
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 14
#         njev: 10
# {'image_rotator': {'phi_h': np.float64(2.574107804533927), 'phi_r': np.float64(0.5221044799330835), 'phi_45': np.float64(1.2043151199100157e-18)}, 'hwp': {'phi': np.float64(2.739559857893639)}, 'wollaston': {'eta': np.float64(0.4345307344300184)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(2.658791656657683), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9483013148482353)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.9904e+00                                    1.19e+01
#        1              2         4.8289e+00      3.16e+00       4.26e-01       2.44e+00
#        2              3         4.4534e+00      3.75e-01       1.87e-01       4.63e-01
#        3              4         4.4215e+00      3.19e-02       1.16e-01       4.72e-02
#        4              5         4.4211e+00      3.98e-04       7.81e-03       8.09e-02
#        5              7         4.4206e+00      4.81e-04       1.54e-02       6.95e-02
#        6              8         4.4204e+00      1.93e-04       2.33e-02       3.18e-03
#        7              9         4.4204e+00      2.43e-06       9.98e-05       3.13e-03
#        8             10         4.4204e+00      2.68e-07       3.07e-04       6.71e-04
#        9             11         4.4204e+00      4.31e-08       2.65e-04       2.70e-04
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 7.9904e+00, final cost 4.4204e+00, first-order optimality 2.70e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 4.885e-01 -1.561e-01 ... -7.066e-01 -1.166e-01]
#            x: [ 2.406e+00  2.947e-07  4.494e-18  2.948e+00  4.360e-01]
#         cost: 4.42041450031549
#          jac: [[-1.951e-01 -4.054e-02 ...  0.000e+00 -4.942e-01]
#                [-1.951e-01  4.054e-02 ...  0.000e+00 -4.942e-01]
#                ...
#                [-9.759e-02  1.041e-01 ...  0.000e+00 -1.698e-01]
#                [-6.858e-02  1.089e-01 ...  0.000e+00 -9.359e-02]]
#         grad: [-6.969e-05  2.588e-02  2.610e+00  0.000e+00 -2.345e-05]
#   optimality: 0.00027020430289158905
#  active_mask: [ 0  0 -1  0  0]
#         nfev: 11
#         njev: 10
# {'image_rotator': {'phi_h': np.float64(2.405890710211025), 'phi_r': np.float64(2.9474810708673483e-07), 'phi_45': np.float64(4.494209848497125e-18)}, 'hwp': {'phi': np.float64(2.9483013148482353)}, 'wollaston': {'eta': np.float64(0.43601990221583575)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(2.329506952088865), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9444303373174208)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.2647e+00                                    9.34e+00
#        1              2         3.9235e+00      2.34e+00       4.05e-01       2.21e+00
#        2              3         3.6056e+00      3.18e-01       1.72e-01       1.09e+00
#        3              4         3.5359e+00      6.97e-02       1.88e-01       1.37e-01
#        4              5         3.5328e+00      3.12e-03       2.06e-02       2.12e-01
#        5              6         3.5320e+00      7.75e-04       2.99e-02       3.40e-02
#        6              7         3.5318e+00      2.69e-04       2.43e+00       1.37e-03
#        7              8         3.5318e+00      1.04e-07       4.19e-04       2.03e-04
#        8              9         3.5318e+00      5.57e-09       3.42e-05       2.80e-05
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.2647e+00, final cost 3.5318e+00, first-order optimality 2.80e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 3.208e-01 -9.537e-02 ... -5.506e-01 -1.271e-01]
#            x: [ 2.183e+00  2.002e-12  2.242e-15  5.168e-01  4.435e-01]
#         cost: 3.5317596133825027
#          jac: [[-2.420e-01 -5.542e-02 ...  0.000e+00 -3.831e-01]
#                [-2.420e-01  5.542e-02 ...  0.000e+00 -3.831e-01]
#                ...
#                [-1.210e-01  1.423e-01 ...  0.000e+00 -1.142e-01]
#                [-8.506e-02  1.489e-01 ...  0.000e+00 -5.451e-02]]
#         grad: [-6.832e-06  2.433e-01  2.344e+00  0.000e+00  8.016e-06]
#   optimality: 2.801323420115342e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 9
#         njev: 9
# {'image_rotator': {'phi_h': np.float64(2.1829137263633194), 'phi_r': np.float64(2.001648055162441e-12), 'phi_45': np.float64(2.241990120604998e-15)}, 'hwp': {'phi': np.float64(0.5168221388226306)}, 'wollaston': {'eta': np.float64(0.44348383762491655)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(2.0376892427031716), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9427243097474256)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.9373e+00                                    7.16e+00
#        1              2         3.3462e+00      1.59e+00       3.48e-01       2.16e+00
#        2              3         2.9661e+00      3.80e-01       2.04e-01       1.13e+00
#        3              4         2.9267e+00      3.95e-02       1.46e-01       2.05e-01
#        4              5         2.9198e+00      6.89e-03       3.26e-02       1.54e-01
#        5              6         2.9193e+00      5.01e-04       2.31e-02       2.43e-02
#        6              7         2.9192e+00      1.10e-04       4.37e-03       2.16e-02
#        7              8         2.9192e+00      7.39e-06       2.81e-03       2.94e-03
#        8              9         2.9192e+00      1.65e-06       5.15e-04       3.58e-03
#        9             10         2.9192e+00      1.81e-07       4.28e-04       4.22e-04
#       10             11         2.9192e+00      3.52e-08       7.48e-05       5.95e-04
#       11             12         2.9192e+00      4.75e-09       6.85e-05       6.42e-05
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 4.9373e+00, final cost 2.9192e+00, first-order optimality 6.42e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 1.520e-01 -3.400e-02 ... -3.833e-01 -1.264e-01]
#            x: [ 1.986e+00  3.352e-11  2.717e-12  2.943e+00  4.458e-01]
#         cost: 2.919157254911941
#          jac: [[-2.720e-01 -6.849e-02 ...  0.000e+00 -2.686e-01]
#                [-2.720e-01  6.849e-02 ...  0.000e+00 -2.686e-01]
#                ...
#                [-1.361e-01  1.758e-01 ...  0.000e+00 -5.698e-02]
#                [-9.561e-02  1.840e-01 ...  0.000e+00 -1.429e-02]]
#         grad: [ 2.288e-06  5.709e-01  1.985e+00  0.000e+00  1.440e-04]
#   optimality: 6.41923339439765e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 12
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(1.9855583402978916), 'phi_r': np.float64(3.352026385741279e-11), 'phi_45': np.float64(2.7172086516308632e-12)}, 'hwp': {'phi': np.float64(2.9427243097474256)}, 'wollaston': {'eta': np.float64(0.4457536610582385)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(1.7689132118012587), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.943422236996289)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.3016e+00                                    5.96e+00
#        1              2         2.9365e+00      1.37e+00       3.41e-01       1.67e+00
#        2              3         2.6880e+00      2.49e-01       2.12e-01       5.07e-01
#        3              4         2.6468e+00      4.11e-02       2.51e+00       6.19e-02
#        4              5         2.6460e+00      8.24e-04       1.18e-02       5.91e-02
#        5              6         2.6460e+00      4.09e-05       6.06e-03       4.55e-03
#        6              7         2.6460e+00      4.70e-06       9.16e-04       4.67e-03
#        7              8         2.6460e+00      2.45e-07       4.67e-04       2.99e-04
#        8              9         2.6460e+00      2.06e-08       6.09e-05       3.27e-04
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.3016e+00, final cost 2.6460e+00, first-order optimality 3.27e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.613e-03  2.348e-02 ... -2.184e-01 -1.091e-01]
#            x: [ 1.818e+00  1.617e-12  8.530e-14  4.363e-01  4.407e-01]
#         cost: 2.645975177433511
#          jac: [[-2.848e-01 -7.831e-02 ...  0.000e+00 -1.634e-01]
#                [-2.848e-01  7.831e-02 ...  0.000e+00 -1.634e-01]
#                ...
#                [-1.425e-01  2.010e-01 ...  0.000e+00 -4.336e-03]
#                [-1.001e-01  2.104e-01 ...  0.000e+00  2.270e-02]]
#         grad: [-7.324e-05  9.648e-01  1.582e+00  0.000e+00  5.624e-06]
#   optimality: 0.0003269828913463608
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 9
#         njev: 9
# {'image_rotator': {'phi_h': np.float64(1.81845352300364), 'phi_r': np.float64(1.6168650801724833e-12), 'phi_45': np.float64(8.529517328422665e-14)}, 'hwp': {'phi': np.float64(0.436275183669419)}, 'wollaston': {'eta': np.float64(0.4406573909484102)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(1.5364262782470774), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.94675578039066)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.2292e+00                                    5.78e+00
#        1              2         2.8429e+00      1.39e+00       3.69e-01       3.28e+00
#        2              3         2.6791e+00      1.64e-01       2.04e-01       6.82e-01
#        3              4         2.6078e+00      7.13e-02       1.04e-01       1.05e-01
#        4              5         2.6054e+00      2.45e-03       2.09e-02       1.31e-02
#        5              6         2.6054e+00      5.42e-06       1.85e-03       2.27e-03
#        6              7         2.6054e+00      1.20e-06       6.41e-04       1.55e-04
#        7              8         2.6054e+00      2.49e-09       3.82e-05       1.77e-05
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 4.2292e+00, final cost 2.6054e+00, first-order optimality 1.77e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-1.410e-01  6.290e-02 ... -4.721e-02 -9.890e-02]
#            x: [ 1.621e+00  8.911e-12  2.663e-11  2.947e+00  4.436e-01]
#         cost: 2.60536402308397
#          jac: [[-2.953e-01 -9.110e-02 ...  0.000e+00 -3.341e-02]
#                [-2.953e-01  9.110e-02 ...  0.000e+00 -3.341e-02]
#                ...
#                [-1.477e-01  2.339e-01 ...  0.000e+00  6.070e-02]
#                [-1.038e-01  2.448e-01 ...  0.000e+00  6.841e-02]]
#         grad: [ 1.091e-05  1.426e+00  1.205e+00  0.000e+00  2.832e-05]
#   optimality: 1.768225972327309e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 8
#         njev: 8
# {'image_rotator': {'phi_h': np.float64(1.6209367113245208), 'phi_r': np.float64(8.911426593674147e-12), 'phi_45': np.float64(2.6634290624578225e-11)}, 'hwp': {'phi': np.float64(2.94675578039066)}, 'wollaston': {'eta': np.float64(0.4435640909295823)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(1.337879684752699), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9529523030518745)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.6614e+00                                    1.18e+01
#        1              2         3.6914e+00      9.70e-01       3.22e-01       3.61e+00
#        2              3         2.8841e+00      8.07e-01       3.17e+00       7.83e-01
#        3              4         2.7913e+00      9.28e-02       1.17e-01       1.10e-01
#        4              5         2.7874e+00      3.87e-03       6.08e+00       1.09e-02
#        5              6         2.7874e+00      3.41e-05       3.67e-03       2.94e-03
#        6              7         2.7874e+00      9.20e-07       6.64e-04       5.75e-04
#        7              8         2.7874e+00      7.67e-08       1.89e-04       1.21e-04
#        8              9         2.7874e+00      1.80e-09       2.71e-05       2.71e-05
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.6614e+00, final cost 2.7874e+00, first-order optimality 2.71e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-2.488e-01  9.732e-02 ...  9.063e-02 -7.894e-02]
#            x: [ 1.472e+00  3.845e-14  4.083e-14  3.057e-02  4.372e-01]
#         cost: 2.787369353011567
#          jac: [[-2.900e-01 -9.855e-02 ...  0.000e+00  6.601e-02]
#                [-2.900e-01  9.855e-02 ...  0.000e+00  6.601e-02]
#                ...
#                [-1.451e-01  2.530e-01 ...  0.000e+00  1.104e-01]
#                [-1.020e-01  2.648e-01 ...  0.000e+00  1.034e-01]]
#         grad: [ 1.841e-05  1.829e+00  8.949e-01  0.000e+00  3.216e-05]
#   optimality: 2.7087830803657404e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 9
#         njev: 9
# {'image_rotator': {'phi_h': np.float64(1.47162078506197), 'phi_r': np.float64(3.845249943638441e-14), 'phi_45': np.float64(4.082793075829442e-14)}, 'hwp': {'phi': np.float64(0.030567152610173842)}, 'wollaston': {'eta': np.float64(0.437212859274055)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(1.1782478110981653), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.962237827816352)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.3620e+00                                    1.82e+01
#        1              2         3.3800e+00      1.98e+00       3.17e+00       2.48e+00
#        2              3         3.0904e+00      2.90e-01       6.07e+00       3.89e-01
#        3              4         3.0660e+00      2.45e-02       6.37e-02       1.36e-01
#        4              5         3.0622e+00      3.80e-03       4.43e-02       3.41e-02
#        5              6         3.0620e+00      1.31e-04       7.43e-03       9.26e-03
#        6              7         3.0620e+00      2.25e-05       3.53e-03       2.99e-03
#        7              8         3.0620e+00      1.19e-06       6.36e-04       8.78e-04
#        8              9         3.0620e+00      1.68e-07       3.42e-04       1.69e-04
#        9             10         3.0620e+00      5.06e-09       3.75e-05       4.82e-05
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 5.3620e+00, final cost 3.0620e+00, first-order optimality 4.82e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.246e-01  1.250e-01 ...  1.835e-01 -4.931e-02]
#            x: [ 1.372e+00  3.209e-14  2.941e-14  4.641e-02  4.245e-01]
#         cost: 3.062013013959167
#          jac: [[-2.775e-01 -1.011e-01 ...  0.000e+00  1.314e-01]
#                [-2.775e-01  1.011e-01 ...  0.000e+00  1.314e-01]
#                ...
#                [-1.388e-01  2.595e-01 ...  0.000e+00  1.431e-01]
#                [-9.754e-02  2.716e-01 ...  0.000e+00  1.263e-01]]
#         grad: [ 3.509e-05  2.115e+00  6.772e-01  0.000e+00  3.892e-05]
#   optimality: 4.815673743579749e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 10
#         njev: 10
# {'image_rotator': {'phi_h': np.float64(1.372416703476147), 'phi_r': np.float64(3.208553479219659e-14), 'phi_45': np.float64(2.941031926921057e-14)}, 'hwp': {'phi': np.float64(0.046406880353951685)}, 'wollaston': {'eta': np.float64(0.42452842528161533)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(1.0458778179531958), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9748400845824543)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.0447e+00                                    2.23e+01
#        1              2         3.7598e+00      2.28e+00       3.00e+00       3.82e+00
#        2              3         3.4689e+00      2.91e-01       2.17e-01       9.73e-01
#        3              4         3.3195e+00      1.49e-01       1.54e-01       2.60e-01
#        4              5         3.3072e+00      1.24e-02       8.59e-02       6.08e-02
#        5              6         3.3067e+00      4.23e-04       1.30e-02       1.97e-02
#        6              7         3.3066e+00      1.21e-04       8.40e-03       9.40e-03
#        7              8         3.3066e+00      1.19e-05       1.92e-03       3.30e-03
#        8              9         3.3066e+00      2.94e-06       1.53e-03       9.39e-04
#        9             10         3.3066e+00      1.64e-07       2.01e-04       3.06e-04
#       10             11         3.3066e+00      2.27e-08       3.16e+00       1.59e-07
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 6.0447e+00, final cost 3.3066e+00, first-order optimality 1.59e-07.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.814e-01  1.427e-01 ...  2.565e-01 -2.649e-02]
#            x: [ 1.286e+00  6.951e-19  3.393e-15  3.167e+00  4.143e-01]
#         cost: 3.306607530976598
#          jac: [[-2.651e-01 -1.031e-01 ...  0.000e+00  1.874e-01]
#                [-2.651e-01  1.031e-01 ...  0.000e+00  1.874e-01]
#                ...
#                [-1.326e-01  2.646e-01 ...  0.000e+00  1.712e-01]
#                [-9.319e-02  2.770e-01 ...  0.000e+00  1.460e-01]]
#         grad: [ 1.238e-07  2.333e+00  5.128e-01  0.000e+00  3.262e-08]
#   optimality: 1.5923065809896392e-07
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 11
#         njev: 11
# {'image_rotator': {'phi_h': np.float64(1.285803389008203), 'phi_r': np.float64(6.950838215099345e-19), 'phi_45': np.float64(3.393122171416955e-15)}, 'hwp': {'phi': np.float64(3.167176323011609)}, 'wollaston': {'eta': np.float64(0.4143411982726061)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.9411728208731114), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(2.9909913816183407)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.8633e+00                                    2.49e+01
#        1              2         4.5456e+00      2.32e+00       5.16e-01       3.49e+00
#        2              3         3.7452e+00      8.00e-01       3.18e+00       7.54e-01
#        3              4         3.6512e+00      9.39e-02       1.13e-01       2.38e-01
#        4              5         3.6386e+00      1.26e-02       6.13e+00       3.93e-02
#        5              6         3.6383e+00      3.09e-04       1.59e-02       7.98e-03
#        6              7         3.6383e+00      3.07e-05       3.22e-03       7.45e-03
#        7              8         3.6383e+00      6.59e-06       1.70e-03       2.84e-03
#        8              9         3.6383e+00      3.45e-06       1.35e-03       2.25e-03
#        9             10         3.6383e+00      6.64e-07       4.54e-04       9.60e-04
#       10             11         3.6383e+00      3.12e-07       4.29e-04       5.47e-04
#       11             12         3.6383e+00      3.56e-08       1.23e-04       2.14e-04
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 6.8633e+00, final cost 3.6383e+00, first-order optimality 2.14e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.291e-01  1.607e-01 ...  3.217e-01  9.478e-03]
#            x: [ 1.211e+00  1.474e-21  1.580e-16  3.078e-02  3.928e-01]
#         cost: 3.638264824290394
#          jac: [[-2.451e-01 -1.012e-01 ...  0.000e+00  2.346e-01]
#                [-2.451e-01  1.012e-01 ...  0.000e+00  2.346e-01]
#                ...
#                [-1.226e-01  2.597e-01 ...  0.000e+00  1.948e-01]
#                [-8.617e-02  2.719e-01 ...  0.000e+00  1.626e-01]]
#         grad: [ 1.763e-04  2.482e+00  3.708e-01  0.000e+00  3.885e-04]
#   optimality: 0.00021350357003982828
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 12
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(1.2112311793474897), 'phi_r': np.float64(1.4742895251716428e-21), 'phi_45': np.float64(1.5797814498826184e-16)}, 'hwp': {'phi': np.float64(0.03077740719825961)}, 'wollaston': {'eta': np.float64(0.3927889466427816)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.8612584400689047), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0109318293578498)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.4433e+00                                    2.61e+01
#        1              2         4.7129e+00      2.73e+00       5.59e-01       3.35e+00
#        2              3         3.9802e+00      7.33e-01       2.60e-01       7.52e-01
#        3              4         3.8525e+00      1.28e-01       3.19e+00       1.39e-01
#        4              5         3.8441e+00      8.44e-03       6.17e+00       2.20e-02
#        5              6         3.8440e+00      1.14e-04       8.58e-03       7.77e-03
#        6              7         3.8440e+00      2.43e-05       3.48e-03       6.07e-03
#        7              8         3.8440e+00      4.60e-06       1.38e-03       2.67e-03
#        8              9         3.8440e+00      3.25e-06       1.27e-03       2.40e-03
#        9             10         3.8440e+00      7.39e-07       4.92e-04       1.14e-03
#       10             11         3.8440e+00      5.10e-07       5.03e-04       8.69e-04
#       11             12         3.8440e+00      1.45e-07       6.25e+00       4.40e-04
#       12             13         3.8440e+00      2.46e-08       1.06e-04       1.86e-04
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 7.4433e+00, final cost 3.8440e+00, first-order optimality 1.86e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.497e-01  1.674e-01 ...  3.642e-01  3.411e-02]
#            x: [ 1.152e+00  7.049e-26  2.910e-14  6.278e+00  3.788e-01]
#         cost: 3.843963184229321
#          jac: [[-2.307e-01 -1.001e-01 ...  0.000e+00  2.710e-01]
#                [-2.307e-01  1.001e-01 ...  0.000e+00  2.710e-01]
#                ...
#                [-1.154e-01  2.570e-01 ...  0.000e+00  2.130e-01]
#                [-8.110e-02  2.690e-01 ...  0.000e+00  1.754e-01]]
#         grad: [ 1.610e-04  2.560e+00  2.904e-01  0.000e+00  3.935e-04]
#   optimality: 0.00018553795607382368
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 13
#         njev: 13
# {'image_rotator': {'phi_h': np.float64(1.1522496126632567), 'phi_r': np.float64(7.049449066812651e-26), 'phi_45': np.float64(2.909855516185481e-14)}, 'hwp': {'phi': np.float64(6.277722297716321)}, 'wollaston': {'eta': np.float64(0.3787514782708647)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.8030305075769144), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0349124963396106)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.8226e+00                                    2.66e+01
#        1              2         4.7960e+00      3.03e+00       5.87e-01       3.21e+00
#        2              3         4.0824e+00      7.14e-01       3.11e+00       7.48e-01
#        3              4         3.9895e+00      9.29e-02       1.08e-01       2.52e-01
#        4              5         3.9736e+00      1.59e-02       1.01e-01       9.91e-02
#        5              6         3.9712e+00      2.43e-03       6.00e+00       7.62e-03
#        6              7         3.9712e+00      8.26e-06       2.13e-03       3.14e-03
#        7              8         3.9712e+00      5.85e-06       1.47e-03       3.70e-03
#        8              9         3.9712e+00      1.76e-06       7.85e-04       1.83e-03
#        9             10         3.9712e+00      1.48e-06       8.16e-04       1.65e-03
#       10             11         3.9712e+00      3.55e-07       3.87e-04       7.69e-04
#       11             12         3.9712e+00      2.95e-07       3.67e-04       7.85e-04
#       12             13         3.9712e+00      8.02e-08       1.62e-04       3.95e-04
#       13             14         3.9712e+00      6.67e-08       1.73e-04       3.44e-04
#       14             15         3.9712e+00      1.59e-08       8.66e-05       1.52e-04
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 7.8226e+00, final cost 3.9712e+00, first-order optimality 1.52e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.564e-01  1.687e-01 ...  3.881e-01  5.449e-02]
#            x: [ 1.108e+00  1.416e-28  8.678e-15  1.334e-01  3.715e-01]
#         cost: 3.9711908339935986
#          jac: [[-2.216e-01 -9.999e-02 ...  0.000e+00  2.975e-01]
#                [-2.216e-01  9.999e-02 ...  0.000e+00  2.975e-01]
#                ...
#                [-1.109e-01  2.567e-01 ...  0.000e+00  2.263e-01]
#                [-7.790e-02  2.687e-01 ...  0.000e+00  1.847e-01]]
#         grad: [ 1.375e-04  2.615e+00  2.435e-01  0.000e+00  3.508e-04]
#   optimality: 0.00015240318816924195
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 15
#         njev: 15
# {'image_rotator': {'phi_h': np.float64(1.108178081476123), 'phi_r': np.float64(1.4159838007862187e-28), 'phi_45': np.float64(8.677833747227646e-15)}, 'hwp': {'phi': np.float64(0.13337593003117743)}, 'wollaston': {'eta': np.float64(0.37145299107521257)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.7635782257098833), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0631989509178603)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.0330e+00                                    2.65e+01
#        1              2         4.6893e+00      3.34e+00       3.09e+00       4.71e+00
#        2              3         4.2649e+00      4.24e-01       2.45e-01       1.15e+00
#        3              4         4.0575e+00      2.07e-01       1.72e-01       3.94e-01
#        4              5         4.0238e+00      3.37e-02       1.54e-01       1.22e-01
#        5              7         4.0219e+00      1.92e-03       2.60e-02       5.95e-02
#        6              8         4.0197e+00      2.21e-03       8.10e-01       6.72e-03
#        7             10         4.0196e+00      7.49e-06       2.18e-03       3.29e-03
#        8             11         4.0196e+00      5.49e-06       1.28e-03       3.67e-03
#        9             13         4.0196e+00      1.82e-06       8.43e-04       1.87e-03
#       10             14         4.0196e+00      3.26e-06       1.01e-01       1.18e-05
#       11             15         4.0196e+00      5.70e-11       2.02e-01       2.33e-08
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 8.0330e+00, final cost 4.0196e+00, first-order optimality 2.33e-08.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.519e-01  1.630e-01 ...  4.100e-01  7.284e-02]
#            x: [ 1.059e+00  2.105e-28  4.880e-21  7.175e-01  3.631e-01]
#         cost: 4.019635040887008
#          jac: [[-2.110e-01 -9.967e-02 ...  0.000e+00  3.268e-01]
#                [-2.110e-01  9.967e-02 ...  0.000e+00  3.268e-01]
#                ...
#                [-1.056e-01  2.559e-01 ...  0.000e+00  2.409e-01]
#                [-7.418e-02  2.678e-01 ...  0.000e+00  1.950e-01]]
#         grad: [-7.572e-10  2.629e+00  2.011e-01  0.000e+00 -3.658e-08]
#   optimality: 2.329952227738055e-08
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 15
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(1.058536942909684), 'phi_r': np.float64(2.1049786835014664e-28), 'phi_45': np.float64(4.880167923153432e-21)}, 'hwp': {'phi': np.float64(0.7174762842982185)}, 'wollaston': {'eta': np.float64(0.3631194802970094)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.740037727221333), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.0960747250300913)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.2227e+00                                    2.64e+01
#        1              2         4.7263e+00      3.50e+00       3.21e+00       4.18e+00
#        2              3         4.3118e+00      4.14e-01       2.37e-01       1.09e+00
#        3              4         4.1124e+00      1.99e-01       1.71e-01       3.99e-01
#        4              5         4.0773e+00      3.50e-02       1.56e-01       1.27e-01
#        5              6         4.0723e+00      5.06e-03       6.24e+00       1.77e-02
#        6              7         4.0722e+00      4.41e-05       4.20e-03       9.37e-03
#        7              8         4.0722e+00      4.66e-05       4.40e-03       1.04e-02
#        8              9         4.0722e+00      4.71e-05       9.60e-03       5.95e-04
#        9             10         4.0722e+00      4.89e-08       1.28e-04       3.36e-04
#       10             11         4.0722e+00      5.64e-08       1.51e-04       3.51e-04
#       11             12         4.0722e+00      1.75e-08       8.34e-05       1.90e-04
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 8.2227e+00, final cost 4.0722e+00, first-order optimality 1.90e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.406e-01  1.549e-01 ...  4.228e-01  9.614e-02]
#            x: [ 1.020e+00  1.159e-23  1.205e-12  3.142e-02  3.526e-01]
#         cost: 4.0721544285969005
#          jac: [[-2.002e-01 -9.819e-02 ...  0.000e+00  3.492e-01]
#                [-2.002e-01  9.819e-02 ...  0.000e+00  3.492e-01]
#                ...
#                [-1.002e-01  2.521e-01 ...  0.000e+00  2.521e-01]
#                [-7.038e-02  2.638e-01 ...  0.000e+00  2.029e-01]]
#         grad: [ 1.865e-04  2.608e+00  1.714e-01  0.000e+00  3.938e-04]
#   optimality: 0.0001901799053054546
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 12
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(1.0195563638871026), 'phi_r': np.float64(1.1588871594194841e-23), 'phi_45': np.float64(1.205450747982168e-12)}, 'hwp': {'phi': np.float64(0.031415926535897754)}, 'wollaston': {'eta': np.float64(0.35255134485457634)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.7275457894546419), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.133845633636237)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.3032e+00                                    2.64e+01
#        1              2         4.7637e+00      3.54e+00       3.16e+00       4.66e+00
#        2              3         4.2998e+00      4.64e-01       2.50e-01       1.18e+00
#        3              4         4.0770e+00      2.23e-01       1.75e-01       4.14e-01
#        4              5         4.0370e+00      4.00e-02       1.67e-01       1.46e-01
#        5              6         4.0342e+00      2.86e-03       3.04e-02       7.93e-02
#        6              7         4.0316e+00      2.58e-03       3.42e-02       6.54e-02
#        7              8         4.0310e+00      6.18e-04       1.63e-02       3.39e-02
#        8              9         4.0304e+00      6.15e-04       1.64e-02       3.71e-02
#        9             10         4.0302e+00      1.92e-04       7.32e-03       2.20e-02
#       10             11         4.0299e+00      2.20e-04       9.53e-03       2.03e-02
#       11             12         4.0299e+00      6.95e-05       6.15e-03       1.00e-02
#       12             13         4.0298e+00      6.72e-05       4.92e-03       1.31e-02
#       13             14         4.0298e+00      2.41e-05       2.63e-03       7.90e-03
#       14             15         4.0298e+00      3.00e-05       3.48e-03       7.77e-03
#       15             16         4.0297e+00      9.73e-06       2.18e-03       4.10e-03
#       16             17         4.0297e+00      1.06e-05       2.08e-03       5.24e-03
#       17             18         4.0297e+00      3.94e-06       1.01e-03       3.21e-03
#       18             19         4.0297e+00      4.83e-06       1.39e-03       3.07e-03
#       19             20         4.0297e+00      5.72e-06       6.25e+00       1.73e-04
#       20             21         4.0297e+00      5.16e-09       5.30e-05       8.80e-05
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 8.3032e+00, final cost 4.0297e+00, first-order optimality 8.80e-05.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-4.168e-01  1.430e-01 ...  4.262e-01  1.163e-01]
#            x: [ 9.880e-01  6.121e-31  1.814e-11  6.264e+00  3.404e-01]
#         cost: 4.029715640922631
#          jac: [[-1.895e-01 -9.590e-02 ...  0.000e+00  3.669e-01]
#                [-1.895e-01  9.590e-02 ...  0.000e+00  3.669e-01]
#                ...
#                [-9.480e-02  2.462e-01 ...  0.000e+00  2.610e-01]
#                [-6.661e-02  2.577e-01 ...  0.000e+00  2.091e-01]]
#         grad: [ 8.902e-05  2.528e+00  1.519e-01  0.000e+00  2.581e-04]
#   optimality: 8.795284687438578e-05
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 21
#         njev: 21
# {'image_rotator': {'phi_h': np.float64(0.9879927104313371), 'phi_r': np.float64(6.121092655469419e-31), 'phi_45': np.float64(1.8141154017089437e-11)}, 'hwp': {'phi': np.float64(6.263922159119238)}, 'wollaston': {'eta': np.float64(0.3404419951093387)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.7296333339397385), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.1768439732586704)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.2053e+00                                    2.61e+01
#        1              2         4.6710e+00      3.53e+00       3.20e+00       4.56e+00
#        2              3         4.1945e+00      4.76e-01       2.50e-01       1.18e+00
#        3              4         3.9684e+00      2.26e-01       1.76e-01       4.23e-01
#        4              5         3.9253e+00      4.32e-02       1.76e-01       1.52e-01
#        5              6         3.9221e+00      3.16e-03       3.08e-02       8.70e-02
#        6              7         3.9190e+00      3.14e-03       3.81e-02       7.08e-02
#        7              8         3.9182e+00      7.55e-04       1.81e-02       3.81e-02
#        8              9         3.9174e+00      8.03e-04       1.91e-02       4.28e-02
#        9             10         3.9165e+00      9.67e-04       6.24e+00       5.13e-03
#       10             11         3.9164e+00      1.75e-05       6.22e+00       3.66e-04
#       11             12         3.9164e+00      1.96e-08       7.14e-05       2.36e-04
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 8.2053e+00, final cost 3.9164e+00, first-order optimality 2.36e-04.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.830e-01  1.269e-01 ...  4.190e-01  1.426e-01]
#            x: [ 9.476e-01  8.508e-22  7.831e-12  3.142e-02  3.309e-01]
#         cost: 3.916447168888879
#          jac: [[-1.791e-01 -9.453e-02 ...  0.000e+00  3.891e-01]
#                [-1.791e-01  9.453e-02 ...  0.000e+00  3.891e-01]
#                ...
#                [-8.962e-02  2.427e-01 ...  0.000e+00  2.721e-01]
#                [-6.298e-02  2.540e-01 ...  0.000e+00  2.169e-01]]
#         grad: [ 2.490e-04  2.439e+00  1.331e-01  0.000e+00  3.402e-04]
#   optimality: 0.00023593221340329187
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 12
#         njev: 12
# {'image_rotator': {'phi_h': np.float64(0.9476006071152566), 'phi_r': np.float64(8.507890290980656e-22), 'phi_45': np.float64(7.831491215164852e-12)}, 'hwp': {'phi': np.float64(0.031415926535897754)}, 'wollaston': {'eta': np.float64(0.33092750453478376)}}
# /tmp/ipykernel_1539814/1452940479.py:19: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('pyPolCal.CHARIS.datacsvs.nbs_in_internalcal_csvs', csvpath) as csvdir:
# {'image_rotator': {'phi_h': np.float64(0.7412513078349483), 'phi_r': 0, 'phi_45': 0}, 'hwp': {'phi': np.float64(3.225433896298193)}, 'wollaston': {'eta': 1}}
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.1378e+00                                    2.62e+01
#        1              2         4.6791e+00      3.46e+00       6.09e-01       3.34e+00
#        2              3         3.9596e+00      7.20e-01       2.44e-01       9.07e-01
#        3              4         3.7688e+00      1.91e-01       1.87e-01       3.96e-01
#        4              5         3.7303e+00      3.85e-02       1.83e-01       1.09e-01
#        5              6         3.7235e+00      6.73e-03       3.21e+00       2.19e-02
#        6              7         3.7235e+00      6.97e-05       4.44e-03       1.45e-02
#        7              8         3.7234e+00      1.15e-04       7.10e-03       1.47e-02
#        8              9         3.7233e+00      3.35e-05       3.46e-03       9.46e-03
#        9             10         3.7233e+00      5.36e-05       4.93e-03       1.08e-02
#       10             11         3.7232e+00      9.53e-05       3.37e+00       4.11e-04
#       11             12         3.7232e+00      1.51e-07       1.49e-02       6.77e-07
#       12             13         3.7232e+00      6.79e-14       1.32e-07       4.72e-07
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 8.1378e+00, final cost 3.7232e+00, first-order optimality 4.72e-07.
# Warning: Jacobian is singular — using pseudo-inverse instead.
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [-3.343e-01  1.094e-01 ...  4.130e-01  1.594e-01]
#            x: [ 9.191e-01  2.279e-26  3.300e-17  3.398e+00  3.104e-01]
#         cost: 3.723181056370978
#          jac: [[-1.645e-01 -8.949e-02 ...  0.000e+00  4.043e-01]
#                [-1.645e-01  8.949e-02 ...  0.000e+00  4.043e-01]
#                ...
#                [-8.230e-02  2.297e-01 ...  0.000e+00  2.797e-01]
#                [-5.783e-02  2.405e-01 ...  0.000e+00  2.223e-01]]
#         grad: [ 5.137e-07  2.232e+00  1.200e-01  0.000e+00  6.855e-07]
#   optimality: 4.7212343912533674e-07
#  active_mask: [ 0 -1 -1  0  0]
#         nfev: 13
#         njev: 13
# {'image_rotator': {'phi_h': np.float64(0.9191318398048373), 'phi_r': np.float64(2.279395852523903e-26), 'phi_45': np.float64(3.2998214045609146e-17)}, 'hwp': {'phi': np.float64(3.398390235526035)}, 'wollaston': {'eta': np.float64(0.31036753083924573)}}
